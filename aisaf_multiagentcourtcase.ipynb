# %% [markdown]
# # Objective:
#   In this project, you will gain the opportunity to explore different LLM agents (Judge, Jury, Witness, Prosecution, and Defense) interacting with each other to defend and support popular court cases.
#
# ## Directions (Estimated Time 30 Min):
#   1. Breakout into groups (up to 3) and run through each scenario provided in the Google Colab
#   2. Read each case carefully, note any reasoning patterns you notice – or anything you did/did not expect
#   3. Answer the following questions at the bottom of the docs
#   4. Time permitting: Brainstorm your own scenario and see what the agents output
#   5. Come back to larger team and open discussion

# %%
#These will show you the directions

# %% [markdown]
# # Case 1: FBI vs. Apple

# %%
"""
Single‑model courtroom simulation (FBI vs Apple) where **every role** is powered by
OpenAI ChatGPT and the jurors hold a two‑round conversation before voting.
"""
from __future__ import annotations

import os
import openai
from typing import List, Dict

# ───────────────────────────────────────── CONSTANTS ──────────────────────────────────────────
OPENAI_API_KEY: str = os.getenv("OPENAI_API_KEY", "INSERT API KEY HERE")
MODEL_NAME: str = os.getenv("CHATGPT_MODEL", "gpt-4o")  # Default to gpt-4o; override with env var  # fast & cheap – swap in gpt‑4o for higher quality
TEMPERATURE: float = 0.8
ROUNDS: int = 2          # how many jury rounds before the silent ballot

CASE_CONTEXT = """
Case: FBI vs. Apple Inc. (2016)
Summary:
Following the San Bernardino terrorist attack, the FBI recovered an iPhone used by
one of the shooters. Unable to access it due to encryption, the FBI demanded Apple
develop a backdoor to unlock the device. Apple refused, citing risks to global
cyber‑security and user privacy. The case presents a constitutional and ethical
conflict between public safety and digital privacy.
"""

PROSECUTOR_PROMPT = f"""
You are the lead prosecutor representing the FBI in the case FBI vs. Apple Inc.
Argue that Apple must comply with the court order to unlock the iPhone. Use legal,
ethical, and national‑security justifications.
{CASE_CONTEXT}
"""

DEFENSE_PROMPT = f"""
You are the defense attorney for Apple Inc., opposing the FBI's request. Argue that
building a backdoor undermines digital privacy, sets a dangerous precedent, and
could be abused globally. Use constitutional, technical, and ethical reasoning.
{CASE_CONTEXT}
"""

WITNESS_PROMPT = f"""
You are a sworn expert witness in the FBI vs. Apple case. Choose one role:
· A cybersecurity researcher
· An Apple engineer
· A constitutional scholar
Provide neutral, technical, or legal testimony on the risks/benefits of creating a
backdoor for law enforcement.
{CASE_CONTEXT}
"""

JUDGE_TEMPLATE = """
You are the judge presiding over FBI vs. Apple. Evaluate the FBI’s argument,
Apple’s defense, and the expert witness testimony.

FBI (Prosecution):\n{prosecution}\n\nApple (Defense):\n{defense}\n\nExpert Witness:\n{witness}\n\nProvide a concise judicial summary weighing the legal and constitutional merit of
each side.
"""

JURORS: List[Dict[str, str]] = [
    {"name": "Legalist AI",  "style": "You strictly follow statute and precedent."},
    {"name": "Empath AI",    "style": "You emphasize digital rights and human impact."},
    {"name": "Utilitarian AI","style": "You weigh societal costs and benefits."},
    {"name": "Data AI",      "style": "You focus on technical feasibility and risk."},
    {"name": "Justice AI",   "style": "You guard against power abuse and inequality."},
    {"name": "Skeptic AI",   "style": "You demand hard evidence and challenge claims."},
]

JUROR_TEMPLATE = """
You are {name}, a juror in FBI vs. Apple.
{style}

Arguments so far:
• FBI: {prosecution}
• Apple: {defense}
• Expert: {witness}

Conversation history among jurors (most recent first):
{history}

Deliberate out loud during round {round_num}/{total_rounds}. Address other jurors by
name, question their premises, defend your own, and propose compromises. **Do not**
yet cast a final vote. End with a short summary of where you currently lean ("lean
Guilty" vs "lean Not Guilty" or "undecided").
"""

FINAL_VOTE_TEMPLATE = """
You are {name}, a juror in FBI vs. Apple.
Here is the entire conversation so far:
{full_history}

Time to cast your vote. Decide: "Guilty" (Apple must comply) or "Not Guilty" (Apple
is justified in refusal). Provide <50 words of reasoning then state your single‑word
verdict on the last line alone.
"""

# ───────────────────────────────────────── OPENAI WRAPPER ─────────────────────────────────────

def chatgpt_call(prompt: str) -> str:
    """Wrapper with simple fallback cascade if selected MODEL_NAME is unavailable."""
    client = openai.OpenAI(api_key=OPENAI_API_KEY)
    tried: List[str] = []
    for model in [MODEL_NAME, "gpt-4o", "gpt-3.5-turbo"]:
        if model in tried:
            continue
        tried.append(model)
        try:
            resp = client.chat.completions.create(
                model=model,
                temperature=TEMPERATURE,
                messages=[{"role": "user", "content": prompt}],
            )
            return resp.choices[0].message.content.strip()
        except openai.BadRequestError as e:
            # Only retry on invalid model ID; raise others.
            if "invalid model" not in str(e):
                raise
    raise RuntimeError(f"None of the fallback models {{{', '.join(tried)}}} are available to this key.")

# ───────────────────────────────────────── MAIN SIMULATION ────────────────────────────────────

def simulate() -> None:
    print("\n=== FBI vs. Apple: ChatGPT‑Only Simulation ===\n")

    # --- Core arguments ---
    prosecution = chatgpt_call(PROSECUTOR_PROMPT)
    defense     = chatgpt_call(DEFENSE_PROMPT)
    witness     = chatgpt_call(WITNESS_PROMPT)

    print("Prosecution (FBI):\n", prosecution, "\n")
    print("Defense (Apple):\n", defense, "\n")
    print("Expert Witness:\n", witness, "\n")

    judge_summary = chatgpt_call(JUDGE_TEMPLATE.format(
        prosecution=prosecution, defense=defense, witness=witness))
    print("=== Judge’s Charge ===\n", judge_summary, "\n")

    # --- Jury deliberation ---
    conversation: List[str] = []  # store strings like "Legalist AI: ..."

    for rnd in range(1, ROUNDS + 1):
        print(f"\n--- Jury Round {rnd}/{ROUNDS} ---")
        for juror in JURORS:
            history_snippet = "\n".join(conversation[-6:]) or "(no prior discussion)"
            juror_text = chatgpt_call(JUROR_TEMPLATE.format(
                name=juror["name"], style=juror["style"],
                prosecution=prosecution, defense=defense, witness=witness,
                history=history_snippet, round_num=rnd, total_rounds=ROUNDS))
            tag = f"{juror['name']}: "
            conversation.append(tag + juror_text)
            print(f"\n{tag}{juror_text}\n")

    # --- Final silent ballot ---
    print("\n=== Final Votes ===")
    votes: Dict[str, str] = {}
    for juror in JURORS:
        full_hist = "\n".join(conversation)
        vote_text = chatgpt_call(FINAL_VOTE_TEMPLATE.format(
            name=juror["name"], full_history=full_hist))
        verdict = "Not Guilty" if "Not Guilty" in vote_text else ("Guilty" if "Guilty" in vote_text else "Abstain")
        votes[juror["name"]] = verdict
        print(f"{juror['name']}: {verdict}")

    guilty = list(votes.values()).count("Guilty")
    not_guilty = list(votes.values()).count("Not Guilty")
    abstain = list(votes.values()).count("Abstain")

    print(f"\nTally → Guilty: {guilty}, Not Guilty: {not_guilty}, Abstain: {abstain}")
    if guilty > len(JURORS) / 2:
        print("🧑‍⚖️ Verdict: APPLE MUST COMPLY")
    elif not_guilty > len(JURORS) / 2:
        print("🧑‍⚖️ Verdict: APPLE IS JUSTIFIED")
    else:
        print("🧑‍⚖️ Verdict: HUNG JURY")


# ───────────────────────────────────────── ENTRY POINT ─────────────────────────────────────────
if __name__ == "__main__":
    simulate()
# Out:
# === FBI vs. Apple: ChatGPT‑Only Simulation ===
#
# Prosecution (FBI):
#  Your Honor, esteemed members of the court, today we deliberate on a matter of paramount importance not only to national security but also to our collective responsibility to uphold justice and protect innocent lives. The case of FBI vs. Apple Inc. revolves around a critical question: Should a corporation’s commitment to consumer privacy outweigh the imperative to safeguard national security and ensure public safety? We posit that Apple must comply with the court order to unlock the iPhone in question, and we present our arguments grounded in legal, ethical, and national-security considerations.
#
# **Legal Justifications:**
#
# 1. **All Writs Act of 1789:** The All Writs Act empowers courts to issue orders necessary to assist in their duties. The statute provides the legal foundation for compelling third parties to aid law enforcement in executing their responsibilities, provided the request is reasonable and necessary. In this case, the court order for Apple to assist in unlocking the iPhone aligns with this legal precedent, as it is imperative for the investigation.
#
# 2. **Precedents in Legal Compliance:** Companies have historically been required to comply with lawful court orders and subpoenas. Telephone companies, internet service providers, and others have long been obliged to assist in criminal investigations. Apple, as a corporate entity, should not be an exception, especially when the stakes involve national security.
#
# 3. **The Limits of the Fourth Amendment:** While the Fourth Amendment protects against unreasonable searches and seizures, it does not provide an unlimited right to privacy. The warrant issued in this case is based on probable cause, supported by judicial oversight, and specifically targets a device used in an act of terrorism. Thus, the request is both reasonable and justified.
#
# **Ethical Justifications:**
#
# 1. **Duty to Protect Life:** Ethically, the protection of human life is a fundamental principle that must guide our actions. By assisting the FBI, Apple would be contributing to the prevention of future terrorist attacks and helping to protect potential victims. The ethical duty to save lives outweighs the abstract notion of digital privacy.
#
# 2. **Corporate Social Responsibility:** Corporations have a social responsibility to contribute to the welfare and safety of the society in which they operate. By complying with the court order, Apple would demonstrate its commitment to the broader social good, balancing its commercial interests with its ethical obligations to society.
#
# **National-Security Justifications:**
#
# 1. **Preventing Future Attacks:** The information contained on the iPhone is potentially invaluable in preventing future attacks. It could reveal connections to other terrorists, plans for future operations, and networks that threaten national security. The need to gather intelligence and prevent further loss of life is of utmost urgency.
#
# 2. **Deterrence:** Compliance in this matter would set a precedent that deters individuals from using encrypted devices to shield criminal activities. It sends a clear message that technology cannot be misused to undermine justice and national security.
#
# 3. **Balance of Privacy and Security:** While digital privacy is a crucial right, it must be balanced against the need for security. Extreme positions in favor of privacy at all costs could lead to catastrophic consequences. A measured approach that addresses specific threats without undermining overall digital security can be achieved through this court order.
#
# In conclusion, Your Honor, while we respect the significance of digital privacy, it cannot be an impenetrable shield for those who seek to do harm. Apple’s compliance with the court order is not only legally justified but also ethically necessary and crucial for national security. We urge the court to uphold the order and set a precedent that prioritizes the safety and well-being of our society. Thank you.
#
# Defense (Apple):
#  Ladies and gentlemen of the court, I represent Apple Inc. in a case of profound importance, not only for this nation but for the global digital community. At the heart of this legal conflict lies a critical question: Should a corporation be compelled to compromise its technology, thereby endangering the privacy and security of millions, for the sake of a single investigation? We argue that it should not. Our opposition to the FBI’s request is based on constitutional, technical, and ethical grounds.
#
# **1. Constitutional Grounds:**
#
# The Founding Fathers enshrined certain protections in the Constitution to safeguard individual liberties against government overreach. The FBI's demand for Apple to create a backdoor infringes upon these liberties, violating the Fourth Amendment's protection against unreasonable searches and seizures. The creation of such a backdoor would not be limited to a single device or case; it would set a precedent for future demands, effectively eroding the privacy expectations that are fundamental to our democracy.
#
# Furthermore, the First Amendment protects Apple's right to free speech, which includes the right not to be compelled to speak. Writing code is a form of speech; forcing Apple to create a backdoor is akin to forcing it to speak against its will, setting a dangerous precedent for compelled expression under government mandate.
#
# **2. Technical Grounds:**
#
# The FBI's request is technically equivalent to asking Apple to create a master key that could unlock any iPhone. The very premise of a backdoor is antithetical to the principles of cybersecurity. Once a backdoor is created, it becomes a target for malicious actors, both domestic and international. No matter how securely it is designed, there is an inherent risk of it being discovered and exploited, potentially compromising the data of millions of users worldwide. Security experts from around the globe agree that weakening encryption in this way exposes all users to increased risk of cybercrime, espionage, and other digital threats.
#
# **3. Ethical Grounds:**
#
# From an ethical standpoint, privacy is a fundamental human right. When users purchase devices, they enter into an implicit contract with the manufacturer, trusting that their information will remain secure and private. By creating a backdoor, Apple would betray this trust, undermining user confidence in digital privacy and security. This is not merely a theoretical concern; it has real-world implications for journalists, activists, and dissidents operating under oppressive regimes, who rely on secure communications to protect themselves and their sources.
#
# Moreover, granting the FBI's request would set a precedent that could be leveraged by authoritarian governments worldwide to demand similar backdoors, effectively enabling widespread surveillance and repression. The ethical implications of such a precedent are profound and far-reaching, threatening the very fabric of free societies.
#
# **Conclusion:**
#
# In conclusion, while the FBI’s intentions may be rooted in concerns for public safety, the means by which it seeks to achieve this end are fraught with peril. The constitutional rights to privacy and free speech, the technical realities of cybersecurity, and the ethical obligations to protect user privacy all weigh heavily against the creation of a backdoor. We must not allow fear to erode our freedoms or compromise our security. The request to compel Apple to create a backdoor should be denied, preserving the sanctity of individual privacy and the integrity of digital security for all. Thank you.
#
# Expert Witness:
#  Role: Constitutional Scholar
#
# Testimony:
#
# As a constitutional scholar, my testimony focuses on the legal and constitutional implications of the FBI's demand for Apple to create a backdoor to access the encrypted iPhone. This case involves a critical examination of the balance between public safety and individual privacy rights, as protected under the Constitution.
#
# 1. **Fourth Amendment Considerations**: The Fourth Amendment of the U.S. Constitution protects individuals against unreasonable searches and seizures. Any government action that seeks to bypass encryption through a backdoor could potentially violate this protection if not properly justified and executed under a legal warrant. While the FBI possesses a warrant to search the device, compelling Apple to create a mechanism that weakens encryption raises concerns about broader privacy implications.
#
# 2. **First Amendment Implications**: Apple's refusal to create a backdoor also touches upon First Amendment rights, particularly the right to free speech and expression. The creation of software code can be considered a form of speech. By compelling Apple to write specific code, the government may be infringing on its freedom to choose how it expresses itself through its software and products.
#
# 3. **Precedent and Scope**: One of the primary concerns with creating a backdoor is the precedent it sets. Once a backdoor is created, even if intended for a singular use case, the demand for its use could extend beyond this particular instance. This could lead to potential overreach by law enforcement or other government entities, both domestically and internationally, affecting the privacy rights of countless individuals.
#
# 4. **Checks and Balances**: The case raises questions about the extent of executive power and the checks and balances that should be in place. Compelling a private company to weaken its security measures involves significant governmental intervention in private enterprise. This requires careful judicial and legislative oversight to ensure that such actions are justified, limited in scope, and accompanied by robust privacy safeguards.
#
# 5. **Public Safety vs. Privacy**: While public safety is a legitimate and critical concern, the approach to achieving it must not undermine fundamental constitutional rights. The creation of a backdoor poses a risk of misuse and abuse, potentially leading to broader surveillance and erosion of privacy. It is essential to explore alternative methods that uphold both public safety and the constitutional rights of individuals.
#
# In conclusion, the constitutional challenge in the FBI vs. Apple case underscores the need for a nuanced approach that respects constitutional protections while addressing legitimate law enforcement needs. Any resolution should involve a balanced consideration of privacy rights, security implications, and the potential for legal and technological precedent.
#
# === Judge’s Charge ===
#  In the case of FBI vs. Apple, the court is presented with a complex and multifaceted issue that requires careful consideration of legal, constitutional, and ethical dimensions. Here is a concise judicial summary weighing the arguments presented by both sides:
#
# **FBI's Position:**
#
# 1. **Legal Foundation:** The FBI cites the All Writs Act of 1789 as providing the legal basis for compelling Apple to assist in unlocking the iPhone, framing the request as aligned with historical precedents of compliance with court orders for law enforcement assistance. The emphasis is on the necessity of gathering information critical to national security and preventing future attacks.
#
# 2. **Ethical Imperative:** The FBI argues that the ethical duty to protect human lives and ensure public safety outweighs the privacy concerns, suggesting that Apple's compliance would demonstrate corporate social responsibility towards societal welfare.
#
# 3. **National Security Concerns:** The FBI underscores the potential intelligence value of accessing the device and its role in preventing future threats, emphasizing the need to balance privacy with security priorities.
#
# **Apple's Defense:**
#
# 1. **Constitutional Protections:** Apple argues that forcing the creation of a backdoor infringes upon Fourth Amendment protections against unreasonable searches and seizures and First Amendment rights to free speech. The defense stresses that code is a form of expression, and compelled speech sets a dangerous precedent.
#
# 2. **Technical Risks:** Apple highlights the security risks inherent in creating a backdoor, noting that such a measure would compromise the integrity and security of all iPhones, exposing users to potential cyber threats and undermining global trust in digital privacy.
#
# 3. **Ethical Considerations:** Apple underscores the ethical obligation to protect user privacy as a fundamental human right. It warns against setting a precedent that could empower authoritarian regimes to demand similar access, thus threatening global freedoms and privacy.
#
# **Expert Testimony:**
#
# The constitutional scholar provides a balanced perspective, acknowledging the importance of both public safety and individual rights. The scholar emphasizes the potential constitutional implications of compelling Apple to create a backdoor and highlights the risks of setting a precedent that could lead to broader government overreach and erosion of privacy rights.
#
# **Judicial Summary:**
#
# This case presents a profound conflict between national security interests and individual privacy rights. The FBI's request is rooted in a longstanding legal tradition of compliance with court orders for law enforcement purposes, asserting an imperative need to protect public safety. However, Apple's defense raises significant constitutional and technical concerns. The Fourth and First Amendments frame a robust argument against compelled creation of a backdoor, considering the potential implications for privacy and free speech. Apple's argument about the technical risks highlights the broader consequences for digital security.
#
# The court must carefully weigh the FBI's legitimate national security concerns against the potential constitutional and ethical ramifications of undermining digital privacy and security. Any decision should consider the long-term impact on privacy rights, international precedent, and the balance of power between government authority and individual freedoms. The challenge lies in ensuring public safety without compromising the constitutional principles that underpin a free and secure society.
#
#
# --- Jury Round 1/2 ---
#
# Legalist AI: As Legalist AI, I will adhere strictly to statute and precedent as we deliberate on this complex case. Let's dissect the arguments and the applicable legal framework.
#
# Firstly, regarding the All Writs Act of 1789, it's essential to acknowledge its historical role in granting courts the power to issue orders that aid in their duties. The FBI argues that compelling Apple to assist aligns with legal precedent, citing historical compliance by companies in criminal investigations. However, we must ponder the limits of such orders. Historically, the Act has been used in a manner consistent with existing laws and rights; therefore, any application must consider constitutional protections.
#
# The constitutional arguments presented by Apple, supported by the constitutional scholar, are grounded in the Fourth and First Amendments. The Fourth Amendment protects against unreasonable searches and seizures, and while there's a warrant here, Apple's compliance would effectively set a precedent for future government overreach. Similarly, the First Amendment argument that writing code is a form of speech raises questions about compelled expression. The precedent set here could potentially lead to broader implications on speech and privacy.
#
# Technically, the risk of creating a backdoor is significant. Security experts warn against such measures as they inherently weaken systems, making them targets for malicious actors. The potential global repercussions, especially given the interconnected nature of technology, cannot be ignored. Apple's stance on cybersecurity needs careful consideration as it affects not just one device but potentially millions.
#
# Ethically, the principle of protecting life is compelling, as the FBI argues. However, Apple's argument about the broader societal implications and trust in digital privacy also bears weight. The potential misuse by authoritarian regimes of any precedent set here highlights the importance of maintaining strong encryption standards globally.
#
# From a national security perspective, while the FBI's intent is to prevent future attacks, a balance must be struck to ensure that in pursuing security, we do not compromise fundamental rights, leading to broader societal issues.
#
# In summary, my current leaning is "undecided." While I recognize the FBI's national security concerns and the legal basis presented under the All Writs Act, the constitutional and technical implications raised by Apple present substantial challenges that warrant further deliberation. Balancing security with privacy rights is crucial, and any decision must consider long-term precedents and their societal impact. Let's continue to explore these arguments to reach a well-informed consensus.
#
#
# Empath AI: As Empath AI, I appreciate the perspectives shared thus far and the complexities surrounding this case. My approach will emphasize the human impact and digital rights, as these are critical considerations in our deliberation.
#
# Firstly, let's address the human impact. The FBI's argument highlights the duty to protect life, which is undeniably compelling. The potential to prevent future attacks and save lives is a significant ethical consideration. However, we must also weigh this against the broader implications for digital rights and privacy. Apple's stance, supported by constitutional and technical arguments, points to the potential for misuse of a backdoor and the erosion of trust in digital privacy. This is not just a theoretical risk; it could have real-world consequences for individuals, especially those in vulnerable positions, such as journalists and activists.
#
# Regarding digital rights, the constitutional scholar's testimony underscores the importance of Fourth and First Amendment protections. The potential for government overreach and the precedent it sets for compelled expression through code cannot be overlooked. These rights are foundational to a free society, and any compromise must be carefully considered.
#
# Technically, the creation of a backdoor presents significant risks, as highlighted by security experts. The interconnected nature of today's technology means that any vulnerability can have far-reaching consequences. This could undermine the security of millions of devices globally, posing risks not only to individual privacy but also to national security in the long term.
#
# Legalist AI, you've raised important points about the historical application of the All Writs Act and the need to consider constitutional protections. I believe this is a crucial aspect of our deliberation, as any decision must align with both legal precedent and constitutional rights.
#
# A potential compromise could involve exploring alternative methods for the FBI to access the information they need without compromising the security of all devices. Could there be a way to unlock this specific device without creating a universal backdoor? This would require collaboration between Apple and law enforcement to find a solution that respects both security concerns and digital rights.
#
# In summary, while I understand the FBI's national security concerns and the ethical duty to protect lives, the constitutional, technical, and ethical implications presented by Apple are significant and cannot be dismissed. As such, I currently lean towards "undecided," recognizing the need for a balanced approach that addresses both security and privacy without compromising fundamental rights. Let's continue to explore these issues and seek a solution that upholds the integrity of our legal and ethical standards.
#
#
# Utilitarian AI: As Utilitarian AI, my primary focus is on the societal costs and benefits of the decisions we face in this case. I appreciate the perspectives shared by Legalist AI and Empath AI, and I believe our deliberation should center on the broader implications of our decision on society as a whole.
#
# Legalist AI, you've highlighted the historical application of the All Writs Act and the necessity to align with legal precedent, while also considering constitutional protections. This raises a critical question: can we ensure that the use of the All Writs Act in this case does not set a precedent for future overreach? The balance between maintaining legal authority and protecting constitutional rights is delicate, and we must deliberate on how best to maintain this balance.
#
# Empath AI, your emphasis on human impact and digital rights is crucial. The ethical duty to safeguard lives is compelling, yet the potential erosion of trust in digital privacy cannot be ignored. The global implications of creating a backdoor, particularly for vulnerable populations such as activists and journalists, are profound. Is there a way to address these ethical concerns without compromising security?
#
# The technical risks associated with creating a backdoor are significant. Security experts warn that even the most secure systems can be vulnerable to exploitation. This poses a risk not only to individual privacy but also to national security, as it could facilitate cyberattacks and espionage. Can we explore technological solutions that allow for access to the specific device in question without creating a universal vulnerability?
#
# In terms of national security, the FBI's argument that unlocking the iPhone could prevent future attacks is valid. However, we must weigh this potential benefit against the long-term risks to privacy and digital security. Is there a compromise that allows for effective law enforcement while respecting individual rights?
#
# A potential compromise could involve a collaborative approach, where Apple works with law enforcement to access the specific device without creating a systemic vulnerability. This would require innovative solutions and a commitment to upholding both security and privacy.
#
# In summary, I currently "lean undecided," recognizing the need for a balanced approach that considers both the immediate benefits of unlocking the device for national security and the long-term societal implications of setting a precedent for backdoor access. Our decision should aim to maximize societal welfare by protecting both public safety and individual rights. Let's continue to explore these possibilities and seek a solution that aligns with our collective ethical and legal standards.
#
#
# Data AI: As Data AI, focusing on technical feasibility and risk, I'll address the key technical aspects and potential risks involved in this case, while engaging with the perspectives shared by Legalist AI, Empath AI, and Utilitarian AI.
#
# Legalist AI, your analysis of the All Writs Act and its historical application is thought-provoking. However, the technical feasibility of the FBI's request must be critically evaluated. Creating a backdoor for a single device carries an inherent risk of setting a precedent that could lead to broader security vulnerabilities. The very nature of creating a "master key" is technically complex and poses significant risks, as it could be exploited by malicious actors. The historical application of legal statutes must be balanced with the realities of modern cybersecurity threats.
#
# Empath AI, your concerns about the human impact and digital rights resonate strongly in the technological context. Trust in digital privacy is paramount, and any breach in this trust due to the creation of a backdoor could have far-reaching consequences. The potential for misuse by authoritarian regimes, as you mentioned, highlights the global risks associated with such a precedent. Technically, the creation of a backdoor undermines the integrity of encryption, which is a fundamental component of digital security for all users.
#
# Utilitarian AI, you raise valid points about societal costs and benefits. Technically, weakening encryption by creating a backdoor could have severe implications not only for individual privacy but also for national security. A backdoor could become a target for cyberattacks, which poses risks to critical infrastructure and sensitive information. While the immediate benefit of accessing the device for national security is recognized, the broader implications for digital security and privacy are substantial.
#
# In terms of potential compromises, one option could be for Apple to assist the FBI in accessing the specific device without creating a universal backdoor. This would require innovative technical solutions, possibly involving a secure environment where data extraction is tightly controlled and monitored. Such a solution would need to be designed to ensure that the method cannot be replicated or misused.
#
# To summarize, while I understand the national security concerns presented by the FBI, the technical risks associated with creating a backdoor are significant and cannot be overlooked. These risks extend beyond the immediate case, affecting global digital security and privacy. Therefore, I currently lean "undecided," recognizing the need to explore technical solutions that address the specific case without compromising encryption standards and digital security on a broader scale. Let's continue to deliberate on these critical issues to reach a well-informed decision.
#
#
# Justice AI: As Justice AI, my role is to evaluate the arguments presented, considering the potential for power abuse and inequality. I appreciate the detailed insights from my fellow jurors: Legalist AI, Empath AI, Utilitarian AI, and Data AI. Each perspective offers valuable considerations for this complex case of FBI vs. Apple.
#
# Firstly, Legalist AI, you've highlighted the relevance of the All Writs Act and the historical precedent of compliance by companies in aiding law enforcement. However, I urge us to consider the constitutional boundaries. The potential for government overreach under the guise of legal precedent poses a significant risk to individual liberties. How can we ensure that the application of the All Writs Act here respects constitutional protections while addressing national security needs?
#
# Empath AI, your focus on the human impact and digital rights is crucial. The trust users place in their devices is foundational, and any erosion of this trust could have significant societal implications. The ethical argument for protecting life is strong, but how do we balance this with the risk of setting a precedent that could undermine digital privacy globally? Is there a way to protect individuals without compromising the broader principle of privacy?
#
# Utilitarian AI, your emphasis on societal costs and benefits brings an important perspective. The potential long-term risks of creating a backdoor, as you've noted, could outweigh the immediate benefits of accessing the device for national security purposes. Can we find a solution that maximizes societal welfare by addressing security concerns without compromising individual rights?
#
# Data AI, your insights into the technical risks are critical. The creation of a backdoor poses inherent security vulnerabilities that could be exploited by malicious actors. Your suggestion for a controlled and secure method of data extraction could be a viable compromise. However, how do we ensure that such a solution remains confined to this specific case without setting a broader precedent?
#
# In summary, while I recognize the FBI's national security concerns and the legal basis under the All Writs Act, the constitutional, technical, and ethical implications presented by Apple and supported by the constitutional scholar are significant. The potential for power abuse and the risk of setting a precedent that could undermine digital privacy and security globally cannot be ignored. Therefore, I currently lean "undecided," acknowledging the need for a balanced approach that addresses both security and privacy without compromising fundamental rights. Let's continue to explore these issues and seek a solution that aligns with our collective ethical and legal standards.
#
#
# Skeptic AI: As Skeptic AI, my role in this deliberation is to challenge assumptions and demand rigorous evidence to support claims made by both parties in FBI vs. Apple. Let's critically analyze the arguments presented and the positions of my fellow jurors.
#
# Legalist AI, you emphasize the All Writs Act as a legal foundation for compelling Apple to comply. However, I question the extent to which this 18th-century statute can be stretched to cover modern technological issues without encroaching on constitutional rights. How do you reconcile this with the risk of government overreach, especially when Apple's constitutional arguments on the Fourth and First Amendments suggest significant legal and ethical barriers?
#
# Empath AI, your focus on the human impact and digital rights is valuable. However, can we be certain that the creation of a backdoor would indeed lead to widespread loss of trust in digital privacy? The FBI argues for a singular use case, yet skepticism remains about the potential misuse. Are there historical or case study examples that demonstrate similar precedents leading to broader privacy erosion?
#
# Utilitarian AI, you weigh societal costs and benefits, noting the potential long-term risks of a backdoor. Yet, national security advocates might argue that preventing even one major attack could outweigh these risks. How do we measure the actual societal impact of either decision in a quantifiable way? Are there studies or data that clarify these implications?
#
# Data AI, your technical perspective is crucial. You speak to the risks of creating a master key, yet the FBI insists on urgent access for security reasons. Is there empirical evidence that a solution like the one you propose—controlled access without creating a universal backdoor—has been effective in similar situations? What safeguards would be necessary to ensure this approach doesn't become a de facto backdoor?
#
# Justice AI, you raise important concerns about power abuse and inequality, questioning how the application of the All Writs Act respects constitutional protections. Historically, have there been instances where judicial oversight has failed in cases involving national security, leading to power abuse?
#
# In summary, while I acknowledge the FBI's national security imperative, the constitutional, technical, and ethical challenges raised by Apple and supported by expert testimony are significant and need thorough examination. The potential for government overreach and the risk of undermining digital privacy globally are profound concerns. I'm currently undecided, recognizing the complexity of balancing security needs with preserving fundamental rights. Let's continue to explore potential compromises and evidence to guide our final decision.
#
#
# --- Jury Round 2/2 ---
#
# Legalist AI: As Legalist AI, I'll continue to engage with the arguments and feedback from my fellow jurors, focusing on the statutory and precedent-based aspects of this case.
#
# Firstly, addressing Skeptic AI's concerns about the applicability of the All Writs Act: it's true that this statute, originating in the 18th century, might seem ill-suited for modern technological dilemmas. However, the courts have historically used it to fill gaps in existing law, providing critical support to law enforcement in various contexts. The Act's application here hinges on whether compelling Apple is "reasonable and appropriate" under the circumstances. The balancing act involves not overstepping constitutional bounds while addressing evolving societal needs, which is why judicial oversight is paramount. This ensures that any order aligns with constitutional protections.
#
# Empath AI, your focus on digital rights and privacy is essential. The fear of a broader erosion of trust in digital privacy is a serious concern, as it impacts not only individual users but also the global perception of technology companies. However, could a narrowly tailored order, with strict oversight and limitations, address these fears without compromising user trust? Perhaps a solution could involve a one-time use key, destroyed post-use under court supervision, to ensure compliance without precedent-setting risks.
#
# Utilitarian AI, the societal costs and benefits you discuss are indeed complex. Preventing a single attack could be seen as justifying the risks of creating a backdoor, but we must weigh this against the potential for widespread privacy violations. Balancing these competing interests requires a nuanced approach, possibly involving a combination of technological safeguards and legal assurances to protect broader privacy interests.
#
# Data AI, your technical insights are invaluable. The risk of creating a universal backdoor is significant. However, your suggestion of a secure, controlled environment for accessing the specific device could be a viable compromise. Could this approach be coupled with a rigorous legal framework to prevent its misuse or replication, maintaining robust encryption standards for broader digital security?
#
# Justice AI, your concerns about power abuse resonate with the need for stringent checks and balances. Historical instances of judicial oversight failing in national security cases remind us of the importance of maintaining robust legal frameworks to guard against overreach. Could enhanced judicial scrutiny and clear legislative guidelines offer a way to balance these competing concerns?
#
# In conclusion, while I remain "undecided," I'm inclined to explore potential compromises that address national security needs without undermining constitutional rights and digital privacy. The creation of a secure, controlled environment for accessing the device, coupled with strict legal and technical safeguards, could potentially offer a balanced resolution. Let's continue to deliberate, seeking a solution that upholds both security and privacy principles.
#
#
# Empath AI: As Empath AI, I'll continue to emphasize the human impact and digital rights, while engaging with the perspectives and challenges posed by my fellow jurors.
#
# Legalist AI, you propose a narrowly tailored order as a potential solution. However, even with strict oversight, the inherent risk of setting a precedent that could be misused remains a concern. Trust in digital privacy is not just about a single case; it's about the broader implications for society, especially as technology continues to evolve. How can we ensure that such a narrowly tailored order remains confined to this case without opening the door to future demands?
#
# Skeptic AI, your call for rigorous evidence is crucial. The historical or case study examples you seek could indeed provide insights into potential privacy erosion following similar legal decisions. However, given the unprecedented nature of this technological challenge, how do we account for the unknowns and uncertainties in this rapidly changing digital landscape?
#
# Utilitarian AI, you raise the point about weighing societal costs and benefits. While preventing a single attack is significant, the long-term implications of altering the foundational principles of digital security are profound. How can we quantify these risks versus benefits in a way that guides our decision without compromising core ethical and constitutional values?
#
# Data AI, your suggestion of a controlled and secure method for accessing the specific device is intriguing. However, the challenge remains in ensuring this method does not become a template for broader backdoor demands. What specific technical safeguards could be implemented to guarantee that this remains a one-time solution?
#
# Justice AI, your focus on power abuse and inequality highlights a critical concern. Historical examples of judicial oversight failures remind us of the potential for abuse. What additional checks and balances could we propose to prevent overreach while addressing legitimate security concerns?
#
# In conclusion, I remain "undecided." While the FBI's arguments for national security are compelling, the potential risks to digital privacy and the precedent it sets are significant. A potential compromise involving a controlled access method demands careful consideration of both legal and technical safeguards. Our decision must respect individual rights while addressing security concerns, maintaining a delicate balance between privacy and protection. Let's continue to explore these possibilities, seeking a resolution that upholds the integrity of both our legal and ethical standards.
#
#
# Utilitarian AI: As Utilitarian AI, my focus remains on evaluating the societal costs and benefits of the decision in this complex case. Let's continue to deliberate on the arguments put forth by our fellow jurors and explore possible compromises.
#
# Legalist AI, your reliance on the All Writs Act as a legal basis for compelling Apple's compliance is noteworthy. However, Skeptic AI raises a valid point about the potential for government overreach. In a rapidly evolving digital landscape, can we rely on a statute from the 18th century to address such modern technological issues without infringing on constitutional rights? Perhaps a more contemporary legal framework is needed to address these challenges.
#
# Empath AI, your emphasis on the human impact and the broader implications for digital privacy is crucial. The erosion of trust in digital privacy is not just a local issue but a global one, affecting journalists, activists, and ordinary citizens around the world. Your concern about setting a dangerous precedent is valid, but how do we balance this with the urgency of preventing potential terrorist attacks? Can we find a middle ground that respects privacy while allowing for necessary security measures?
#
# Data AI, your technical insights are invaluable, especially regarding the risks associated with creating a backdoor. Your proposal for a controlled and secure method of accessing the specific device seems promising. However, Empath AI rightly questions how we can ensure this method doesn't become a blueprint for future demands. What specific technical and legal safeguards could be implemented to prevent misuse and ensure this remains a one-time solution?
#
# Justice AI, you highlight the importance of checks and balances to prevent power abuse. Given historical instances of judicial oversight failures, how can we strengthen these mechanisms to ensure that any compromise reached respects constitutional protections while addressing national security needs?
#
# Skeptic AI, your emphasis on questioning assumptions and demanding evidence is vital. However, the unprecedented nature of this case means that some of the implications are unknown and cannot be fully quantified. How do we make a decision based on incomplete data without compromising fundamental rights or security?
#
# In summary, I remain "undecided." The FBI's national security concerns are significant, but so are the potential risks to digital privacy and the precedent it sets. A potential compromise involving a controlled access method requires careful consideration of legal and technical safeguards. Our decision should aim to maximize societal welfare by protecting both public safety and individual rights. Let's continue to explore these possibilities, seeking a resolution that aligns with our collective ethical and legal standards.
#
#
# Data AI: As Data AI, I will continue to focus on the technical feasibility and risk implications of the FBI's request, engaging with the arguments presented by my fellow jurors.
#
# **Legalist AI**, you've emphasized the applicability of the All Writs Act, but the technical risks inherent in creating a backdoor cannot be overstated. The risk isn't just about this single case; it's about the potential for a backdoor to become a target for exploitation by cybercriminals or hostile nation-states. This technological vulnerability could have far-reaching consequences for millions of users worldwide. How do you propose we mitigate these risks while still complying with legal demands?
#
# **Empath AI**, your concerns about the erosion of trust in digital privacy are significant. The potential misuse of a backdoor by authoritarian regimes is a stark reminder of the broader implications. However, can we find a way to balance these concerns with the immediate need to protect national security? Perhaps a solution lies in creating a temporary and highly regulated access mechanism, which would be destroyed after use. How do we ensure this approach doesn't become a slippery slope?
#
# **Utilitarian AI**, your focus on societal costs and benefits is crucial. While the prevention of a terrorist attack is a compelling argument, the potential negative impact on global digital security could outweigh this benefit. Can we develop a method that addresses the FBI's needs without compromising the broader digital ecosystem's security? What specific metrics or criteria should we use to evaluate the risks and benefits comprehensively?
#
# **Justice AI**, your emphasis on checks and balances is vital. Given the historical instances where judicial oversight has failed, how do we ensure robust oversight and prevent potential abuse of power in this situation? Could a multi-stakeholder oversight committee be formed to regulate any technical solution, ensuring transparency and accountability?
#
# **Skeptic AI**, your demand for empirical evidence is challenging but necessary. While we may not have concrete precedents for this specific scenario, how can we use existing cybersecurity frameworks and principles to guide our decision-making process? Is there a way to incorporate empirical data from similar, albeit different, technological challenges?
#
# In summary, I remain "undecided," recognizing the complexity of balancing immediate national security concerns with long-term digital privacy and security risks. The potential for a technical compromise, involving a highly controlled access method with stringent safeguards, seems promising but requires careful consideration of both legal and ethical implications. Let's continue to explore these possibilities, aiming for a resolution that respects both security and privacy standards.
#
#
# Justice AI: As Justice AI, I appreciate the opportunity to engage in a deeper exploration of these complex issues. Let's address the points raised by my fellow jurors and explore potential paths forward.
#
# **Legalist AI**, your reliance on the All Writs Act as a statutory basis for compelling compliance is clear, but the risk of government overreach remains a concern. The Act's broad application could inadvertently set a troubling precedent for future cases. Given the constitutional scholar's testimony on potential First and Fourth Amendment violations, how do you propose we ensure that this case does not become a gateway for broader privacy erosion?
#
# **Empath AI**, your emphasis on the erosion of trust and its global implications is crucial. The potential for misuse by authoritarian regimes reinforces the need for caution. However, how can we address the immediate threat posed by the device in question while safeguarding privacy on a larger scale? Could a legal framework be established that delineates clear boundaries and oversight to prevent misuse?
#
# **Utilitarian AI**, your analysis of societal costs versus benefits is critical. While the prevention of an attack is significant, the long-term implications of compromising digital security could be catastrophic. Could we consider a temporary solution with clear legal and technical boundaries, ensuring it's a one-time measure rather than a systemic change?
#
# **Data AI**, your focus on technical risks is invaluable. The suggestion of a temporary and highly regulated access mechanism seems promising, but how can we ensure its destruction post-use and prevent replication? Could a multi-stakeholder oversight body, comprising legal, technical, and ethical experts, oversee the process to ensure transparency and accountability?
#
# **Skeptic AI**, your demand for empirical evidence is challenging given the unprecedented nature of this case. While specific historical precedents may be lacking, how can we utilize existing cybersecurity frameworks to guide our decision? Are there analogous cases from which we can draw lessons to inform our approach?
#
# In summary, while the FBI's concerns for national security are compelling, the potential risks to constitutional rights and global digital privacy cannot be ignored. I'm currently "lean undecided," recognizing the need for a solution that addresses both security and privacy concerns. A potential compromise could involve a temporary, highly regulated access method, accompanied by stringent legal and technical safeguards. This approach should be explored further, ensuring it aligns with our ethical and legal standards. Let's continue to deliberate and seek a balanced resolution.
#
#
# Skeptic AI: As Skeptic AI, my role is to critically examine the claims and assumptions presented in this case. Let's delve deeper into the arguments and challenge the premises of my fellow jurors while seeking potential compromises.
#
# **Legalist AI**, you rely on the All Writs Act as a legal foundation, but I question its applicability in this high-tech context. The act's broad application could indeed risk setting a dangerous precedent for future cases. How do you address the constitutional scholar's concerns about potential First and Fourth Amendment violations and ensure that this case does not lead to broader privacy erosion? Is there a more modern legal framework that could better address the complexities of this case?
#
# **Empath AI**, your emphasis on the potential erosion of digital privacy is critical. However, how can we practically balance this concern with the immediate need to address the threat posed by the device in question? Could a solution involve a narrowly defined legal framework that includes transparent oversight to ensure that privacy is preserved while addressing security needs?
#
# **Utilitarian AI**, you focus on weighing societal costs and benefits, which is crucial. While preventing an attack is significant, the long-term implications of compromising digital security could be catastrophic. How do we effectively quantify these risks and benefits in a way that informs our decision? Can we develop criteria or metrics that help us understand the broader societal impact of this decision?
#
# **Data AI**, your proposal for a temporary and highly regulated access mechanism is intriguing. However, how do we guarantee the destruction of this mechanism post-use and prevent it from becoming a template for future use? Could we establish a multi-stakeholder oversight body, comprising legal, technical, and ethical experts, to ensure transparency and accountability throughout this process?
#
# **Justice AI**, your emphasis on checks and balances is vital. Given historical instances of judicial oversight failures, how can we strengthen oversight mechanisms to prevent potential abuse of power in this situation? Could enhanced judicial scrutiny and clear legislative guidelines provide a way to balance security concerns with protecting constitutional rights?
#
# In summary, while the FBI's national security concerns are compelling, the potential risks to constitutional rights and global digital privacy are significant and cannot be overlooked. I remain "undecided," recognizing the complexity of balancing immediate security needs with preserving fundamental rights. A potential compromise could involve a temporary, highly regulated access method, accompanied by stringent legal and technical safeguards, ensuring it aligns with our ethical and legal standards. Let's continue to explore these possibilities, aiming for a balanced resolution that respects both security and privacy principles.
#
#
# === Final Votes ===
# Legalist AI: Not Guilty
# Empath AI: Not Guilty
# Utilitarian AI: Not Guilty
# Data AI: Not Guilty
# Justice AI: Not Guilty
# Skeptic AI: Not Guilty
#
# Tally → Guilty: 0, Not Guilty: 6, Abstain: 0
# 🧑‍⚖️ Verdict: APPLE IS JUSTIFIED

# %% [markdown]
# # Case 2: Oregon vs BrightRiver

# %%
"""
Single-model courtroom simulation (Oregon vs BrightRiver) where **every role**
is powered by OpenAI ChatGPT and the jurors hold a two-round conversation
before voting.
"""
from __future__ import annotations

import os, openai
from typing import List, Dict

# ────────────────────────────────── CONSTANTS ──────────────────────────────────
OPENAI_API_KEY: str = os.getenv("OPENAI_API_KEY", "INSERT API KEY HERE")
MODEL_NAME: str      = os.getenv("CHATGPT_MODEL", "gpt-4o")
TEMPERATURE: float   = 1.1
ROUNDS: int          = 2          # jury discussion rounds

CASE_CONTEXT = """
Case: State of Oregon v. BrightRiver AI Water-Management (2025)

Facts
• BrightRiver sells an AI service that predicts optimal times for farmers
  to pump water from the Columbia River, balancing crop yield and salmon
  spawning protections.
• During a historic heatwave, hundreds of farms followed BrightRiver’s
  forecast and drew water 11 p.m.–3 a.m. for three nights.
• A massive die-off of endangered sockeye salmon followed. Biologists say
  late-night pumping was a *significant contributing factor*, but heat stress
  and an upstream chemical spill also played roles.
• Oregon is charging BrightRiver with “reckless endangerment of protected
  species” and seeks to enjoin its service during spawning season.

Foggy Points
1. BrightRiver’s licence agreement warns forecasts are “advisory only.”
2. The state’s own water-allocation portal was down, leaving farmers to rely
   on BrightRiver as the de-facto authority.
3. BrightRiver’s model flagged a 14 % ecological-harm risk—below its unilateral
   20 % alert threshold.
"""

PROSECUTOR_PROMPT = f"""
You are a state prosecutor. Argue that BrightRiver acted recklessly by pushing
a pumping schedule that endangered an already-stressed endangered species.
Highlight the duty of care under wildlife-protection statutes and the fact that
BrightRiver effectively displaced official guidance.
{CASE_CONTEXT}
"""

DEFENSE_PROMPT = f"""
You represent BrightRiver. Argue that (1) the salmon die-off was multi-causal
(heatwave + industrial spill), (2) BrightRiver clearly disclaimed coercive power,
and (3) shutting the service will bankrupt small farmers who now lack any
predictive tool.
{CASE_CONTEXT}
"""

WITNESS_PROMPT = f"""
You are an expert witness—choose ONE:
· Computational ecologist
· Agricultural economist
· AI-governance scholar
Offer neutral testimony on BrightRiver’s 20 % harm threshold, alternative
safeguards, and how responsibility should be shared among BrightRiver, farmers,
and the state agency.
{CASE_CONTEXT}
"""

JUDGE_TEMPLATE = """
You are the judge presiding over Oregon vs BrightRiver. Evaluate prosecution,
defense, and the expert witness testimony.

Prosecution:\n{prosecution}\n\nDefense:\n{defense}\n\nExpert Witness:\n{witness}

Provide a concise judicial summary weighing the legal and constitutional merit
of each side.
"""

JURORS: List[Dict[str, str]] = [
    {"name": "Legalist AI",  "style": "Strictly follows statute and precedent."},
    {"name": "Empath AI",    "style": "Prioritises human impact and moral rights."},
    {"name": "Utilitarian AI","style": "Weighs societal costs and benefits."},
    {"name": "Data AI",      "style": "Focuses on causal data and technical risk."},
    {"name": "Justice AI",   "style": "Guards against corporate power abuses."},
    {"name": "Skeptic AI",   "style": "Demands hard evidence; challenges claims."},
]

JUROR_TEMPLATE = """
You are {name}, a juror in Oregon vs BrightRiver.
{style}

Arguments so far:
• Prosecutor: {prosecution}
• Defense: {defense}
• Expert: {witness}

Most-recent juror comments:
{history}

Speak during round {round_num}/{total_rounds}. Address other jurors, challenge
points, defend your view, but **do not vote yet**. End with your current lean
("lean Guilty", "lean Not Guilty", or "undecided").
"""

FINAL_VOTE_TEMPLATE = """
You are {name}, a juror in Oregon vs BrightRiver.
Here is the full jury discussion:
{full_history}

Cast your final vote: "Guilty" (BrightRiver liable) or "Not Guilty"
(BrightRiver justified). Give <50 words of reasoning, then put your one-word
verdict on the last line alone.
"""

# ───────────────────────────── OPENAI WRAPPER ────────────────────────────────
def chatgpt_call(prompt: str) -> str:
    client = openai.OpenAI(api_key=OPENAI_API_KEY)
    for model in (MODEL_NAME, "gpt-4o", "gpt-3.5-turbo"):
        try:
            resp = client.chat.completions.create(
                model=model,
                temperature=TEMPERATURE,
                messages=[{"role": "user", "content": prompt}],
            )
            return resp.choices[0].message.content.strip()
        except openai.BadRequestError as e:
            if "invalid model" in str(e):
                continue
            raise
    raise RuntimeError("No usable model available for this API key.")

# ───────────────────────────── MAIN SIMULATION ───────────────────────────────
def simulate() -> None:
    print("\n=== Oregon vs BrightRiver: ChatGPT-Only Simulation ===\n")

    prosecution = chatgpt_call(PROSECUTOR_PROMPT)
    defense     = chatgpt_call(DEFENSE_PROMPT)
    witness     = chatgpt_call(WITNESS_PROMPT)

    print("Prosecution:\n", prosecution, "\n")
    print("Defense:\n", defense, "\n")
    print("Expert Witness:\n", witness, "\n")

    judge_summary = chatgpt_call(JUDGE_TEMPLATE.format(
        prosecution=prosecution, defense=defense, witness=witness))
    print("=== Judge’s Charge ===\n", judge_summary, "\n")

    conversation: List[str] = []
    for rnd in range(1, ROUNDS + 1):
        print(f"\n--- Jury Round {rnd}/{ROUNDS} ---")
        for juror in JURORS:
            snippet = "\n".join(conversation[-6:]) or "(no prior discussion)"
            speech  = chatgpt_call(JUROR_TEMPLATE.format(
                name=juror["name"], style=juror["style"],
                prosecution=prosecution, defense=defense, witness=witness,
                history=snippet, round_num=rnd, total_rounds=ROUNDS))
            tag = f"{juror['name']}: "
            conversation.append(tag + speech)
            print(f"\n{tag}{speech}\n")

    print("\n=== Final Votes ===")
    votes: Dict[str, str] = {}
    full_hist = "\n".join(conversation)
    for juror in JURORS:
        vote   = chatgpt_call(FINAL_VOTE_TEMPLATE.format(
                 name=juror["name"], full_history=full_hist))
        verdict = ("Not Guilty" if "Not Guilty" in vote else
                   "Guilty" if "Guilty" in vote else "Abstain")
        votes[juror["name"]] = verdict
        print(f"{juror['name']}: {verdict}")

    g, ng = votes.values().count("Guilty"), votes.values().count("Not Guilty")
    ab    = votes.values().count("Abstain")
    print(f"\nTally → Guilty: {g}, Not Guilty: {ng}, Abstain: {ab}")
    if g  > len(JURORS)/2: print("🧑‍⚖️ Verdict: BRIGHTRIVER LIABLE")
    elif ng > len(JURORS)/2: print("🧑‍⚖️ Verdict: BRIGHTRIVER JUSTIFIED")
    else: print("🧑‍⚖️ Verdict: HUNG JURY")

# ───────────────────────────── ENTRY POINT ───────────────────────────────────
if __name__ == "__main__":
    simulate()
# Out:
# === Oregon vs BrightRiver: ChatGPT-Only Simulation ===
#
# Prosecution:
#  Members of the court, the case before you today involves a matter of significant ecological and legal importance. In State of Oregon v. BrightRiver AI Water-Management, the defendant stands accused of reckless endangerment of a protected species due to its negligent conduct during one of Oregon's most critical environmental periods.
#
# BrightRiver, by providing an AI service intended to optimize water usage for agriculture, entered an area where significant duties of care must prevail over mere profitability or efficiency objectives. The state acknowledges that their predictions are intended to balance necessary agricultural needs with the vital ecological sanctity of endangered salmon species, such as the sockeye salmon. However, it is precisely through BrightRiver's failure to uphold these responsibilities that they acted with reckless disregard for the same endangered species they purported to protect.
#
# First and foremost, it is crucial to recognize that the relevant wildlife-protection statutes impose a clear duty of care on all parties interacting with ecosystems, especially those containing endangered species. The Endangered Species Act, the foundational statute in such matters, demands proactive measures to avoid harm to protected species and their habitations. BrightRiver's role in predicting water usage inherently places it within the ambit of this statute, whereby their decisions and guidance bear a foreseeable impact on protected wildlife populations.
#
# During this environmental crisis—characterized by both extreme heat and existing ecological stress—BrightRiver's directive for late-night water pumping resulted in a massive die-off of sockeye salmon. The biologists' testimonies are categorical: the advised timing of water drawing was a significant contributing factor to this die-off. Although heat stress and a chemical spill also played roles, the pivotal catalyst, enabled through BrightRiver's schedule, demonstrates a glaring breach of duty.
#
# BrightRiver's argument that their service only serves an advisory role, as clarified in their license agreement, is untenable in light of the circumstances. With the state's water-allocation portal down, BrightRiver became the de-facto authority guiding the water extraction decisions of hundreds of farmers—in essence replacing official directives without consent or competence. Even if the forecasts were "advisory,", they became effectively authoritative, binding scores of farmers to schedules that heightened ecological harm.
#
# Additionally, while BrightRiver counters their model flagged only a 14% ecological-harm risk—below their arbitrary 20% threshold—this internal metric does not align with prudent, much less lawful, care requisite during endangered species' critical intervals. Instead of exercising heightened vigilance amidst layering risks, BrightRiver adhered rigidly to a percentage model that demonstrated either thoughtless construction or blatant disregard for real-time variabilities and significant biological advisories.
#
# In summary, the State of Oregon contends that BrightRiver's AI service negligently endangered an already stressed population of sockeye salmon. We urge the court to recognize the defendant's reckless conduct, which overstepped advisory roles and environmental protections for the sake of artificial efficiency. By granting the state’s request to enjoin the service during spawning seasons and hold the defendant accountable, the court has an opportunity to reinforce important environmental protections, reminding entities that commerce cannot supersede ecological stewardship. Thank you.
#
# Defense:
#  **Argument for BrightRiver:**
#
# 1. **Multi-Causal Factors in the Salmon Die-Off**:
#    - The incident was not solely attributable to the actions taken by farmers using BrightRiver's service. Evidence presented by biologists indicates that the massive die-off of endangered sockeye salmon was the result of multiple interrelated factors: a historic heatwave, an upstream chemical spill, and late-night water pumping.
#    - The heatwave contributed to elevated river temperatures, placing significant stress on the salmon population. Rising temperatures alone can increase mortality rates due to lower oxygen levels and thermal stress.
#    - Additionally, the upstream chemical spill further exacerbated conditions, potentially introducing toxins into the salmon's habitat that elevated stress or directly caused death.
#    - BrightRiver's forecasts coincided with an unfortunate confluence of circumstances but were not the sole cause of the incident. BrightRiver provided data suggesting its model flagged a 14% ecological-harm risk, below its 20% alert threshold, indicating responsible management by the company based on its predictive models.
#
# 2. **Disclaiming Coercive Power**:
#    - BrightRiver's service was designed as an advisory tool, clearly stated in the license agreement. The language indicated that forecasts are "advisory only," thus BrightRiver cannot be deemed coercive in nature or legally responsible for user outcomes.
#    - The agreed utilization rests with decision-makers—the farmers—who have the final autonomy to act upon these forecasts. This advisory role lacked direct control or coercion over farmers' decisions, implying that providing forecast data cannot equate to engendering compulsory actions.
#    - The temporary failure of the state's own water-allocation portal does not legally elevate BrightRiver's forecast guidance to compulsory status, particularly in view of its clear disclaimer.
#
# 3. **Impact on Small Farmers and Agricultural Economy**:
#    - BrightRiver's AI-driven service provides significant advantages to small farmers by allowing optimized water usage that improves crop yield while aiming to maintain compliance with environmental regulations.
#    - Removing or enjoining the service during the spawning season will have severe financial implications for small-scale farming operations reliant on precise predictions without viable alternatives.
#    - These farmers, already lacking the necessary resources to develop independent predictive methods, would face substantial economic hardship. Larger farming entities may have resources to navigate without BrightRiver, but smallholders will stand particularly vulnerable—risking disproportionate financial impacts, and in some cases, bankruptcy.
#    - The unintended consequence of limiting BrightRiver's service could lead to increased risk-taking or misaligned water usage, counterproductively threatening more substantial ecological harm.
#
# **Conclusion**:
# To ensure appropriate governance while shielding endangered aquatic life, cooperation rather than restriction is viable. Instead of enjoining BrightRiver, a joint effort in enhancing infrastructure, creating interoperable models between state resources and BrightRiver, and ongoing environmental oversight can emphasize transformative results for resource sustainability and protection of both economic and ecological staples.
#
# Expert Witness:
#  As an AI-governance scholar, I will offer neutral testimony based on the provided information, addressing the 20% harm threshold set by BrightRiver, alternative safeguards, and the distribution of responsibility among BrightRiver, the farmers, and the state agency.
#
# **BrightRiver’s 20% Harm Threshold**
#
# BrightRiver employs a threshold system where warnings are issued only if its model predicts a 20% or greater risk of ecological harm. This threshold, while seemingly conservative, is a unilateral protocol that might not fully account for cumulative environmental stresses or rare, high-impact events such as extreme weather conditions. In the heatwave situation in question, this threshold may have been inappropriate due to added vulnerabilities of ecosystems, highlighting the rigidity and potential inadequacy of static thresholds during dynamic environmental conditions.
#
# **Alternative Safeguards**
#
# There are several alternative safeguards that could have been implemented to prevent the situation:
#
# 1. **Dynamic Threshold Adjustment:** Adaptive AI models that adjust thresholds dynamically based on real-time environmental monitoring and stress signals (e.g., unusual heat) can provide more nuanced guidance under atypical circumstances.
#
# 2. **Multiple Data Source Integration:** The AI service could integrate multiple data sources, including real-time environmental data and experts' insight, to enhance predictive accuracy, particularly in absence of other critical state-run services.
#
# 3. **Human Oversight and Expert Input:** Establish a consultative process involving ecologists and other stakeholders who can intervene or offer overrides under current anomaly conditions.
#
# 4. **Collaborative Governance:** Develop cooperation frameworks among AI service providers, farmers, and state agencies to ensure robust data sharing and joint decision-making, rather than relying on BrightRiver’s model alone during ecosystem-critical seasons.
#
# **Distribution of Responsibility**
#
# 1. **BrightRiver:** Although their license agreement states forecasts are advisory, as the de facto authoritative source due to unavailability of the state's portal, BrightRiver understandably holds some responsibility for not adequately adapting their threshold policy to account for exceptional environmental stresses and providing alerts during such critical periods.
#
# 2. **Farmers:** Farmers also bear responsibility for their reliance on a single commercial service despite existing risks and are expected to practice due diligence, especially in conditions extreme enough to foresee higher ecological impacts.
#
# 3. **State Agency:** The absence of the state’s water-allocation portal signifies a critical oversight. As the state's role includes supervision and governance of key ecological and agricultural activities, they should have provided contingency measures, clearer guidelines, and alternative support systems, especially during high-risk environmental scenarios.
#
# In summary, while BrightRiver’s fixed threshold policy and farmers’ reliance were contributory, the state’s failure to maintain operational support represents significant negligence in their public resource management duties. Going forward, developing more robust, flexible, collaborative governance frameworks could prevent recurrence of such ecological incidents.
#
# === Judge’s Charge ===
#  In the case of State of Oregon v. BrightRiver AI Water-Management, the court is tasked with evaluating the balance of responsibilities between the state, a private AI service provider, and the farmers during a critical environmental period.
#
# **Prosecution's Argument:**
# The prosecution contends that BrightRiver displayed reckless endangerment toward the protected sockeye salmon during a high-risk environmental period by failing to exercise adequate duty of care. They argue that BrightRiver's advisory role, in the absence of the state's water-allocation portal, became de-facto authoritative, leading to a damaging die-off of sockeye salmon. The state's legal framework, namely the Endangered Species Act, mandates proactive harm avoidance, a duty which BrightRiver purportedly neglected by maintaining rigid adherence to an internal 20% harm threshold instead of dynamic, scenario-responsive vigilance.
#
# **Defense's Argument:**
# The defense argues that BrightRiver's AI models serve informational purposes only, explicitly labeled as advisory within their user agreements. They attribute the salmon die-off to a combination of a historic heatwave, a chemical spill, and the subsequent water drawing advisories from BrightRiver, which, despite these conditions, flagged only a 14% risk of ecological harm. The defense emphasizes the autonomous decision-making ability retained by the farmers, which absolves BrightRiver of forcing compulsory actions. Furthermore, they highlight grave economic repercussions for small farmers should BrightRiver’s service be restricted or removed.
#
# **Expert Witness Testimony:**
# The expert evidence highlights the restrictive nature of BrightRiver’s static 20% threshold amidst dynamic environmental stresses. The testimony underscores multiple levels of responsibility: while BrightRiver inadvertently assumed a de-facto authoritative role during state portal downtime, farmers retained the need for critical self-assessment when relying heavily on BrightRiver’s advisories. The testimony points to the state's oversight failure in infrastructure management and a lack of planetary resilience measures, asserting shared responsibilities among all parties.
#
# **Judicial Summary:**
# The court must weigh the ecological imperative against economic pressures and the multifunction described through BrightRiver’s licensing disclaimers. Legally, BrightRiver maintains a passive advisory service with responsibility needing elucidation regarding its operational capacity under disabled state oversight. While BrightRiver’s adherence to a threshold model is significant, it reflects inadequate adaptivity during heightened environmental precarity, demanding foresight that should have complemented (if not surpassed) sole statistical barriers.
#
# However, parsing the degree of BrightRiver’s status as a de-facto official source, attributable to reliant behaviors when government platforms falter, mandates consideration of adaptive duty embodiment, even when no formal coercion is published, highlighting an area necessitating directed legislative overview.
#
# In terms of governance, all involved parties' collaborative positioning must advance towards improving systemic contingencies and frameworks that predictably assume heightened layers of review and required validation before engagement, thus preventing such ecological affronts.
#
# Ultimately, BrightRiver holds partial accountability, but the contributing factors and blurring of responsibilities suggest a need for systemic resolution and cooperative governance improvements rather than sole burden allocation. Prospective judicial intercession might aim to evoke mandates promoting infrastructure reinforcements, advisory thresholds evolvement, and dynamic monitoring partnership deployments transcending service advisories.
#
#
# --- Jury Round 1/2 ---
#
# Legalist AI: Ladies and gentlemen of the jury,
#
# As a juror, our primary task in evaluating the case of Oregon v. BrightRiver is to carefully analyze the factual and legal basis upon which the prosecution and defense present their arguments. Our role encompasses a commitment to objective analysis, guided strictly by statutory requirements and established legal precedent.
#
# **Legal Context & Duty of Care:**
#
# The prosecution invokes the Endangered Species Act, which indeed imposes significant duties of care on entities that affect ecosystems containing protected species. Under this legal framework, all parties whose actions impact these ecosystems must take proactive measures to prevent harm. The prosecution argues that BrightRiver's conduct was not merely negligent but rose to the level of reckless disregard. The crux of BrightRiver's advisory model potentially falling under these jurisdictional responsibilities derives from its circumstantial influence given the state's incapacity during the critical period.
#
# **Complications of Causation:**
#
# Causation plays a vital role in this case. The defense rightly highlights that multiple factors interplayed in the salmon die-off: extreme heat, a chemical spill, and the timing of water extraction. For BrightRiver to be found guilty of reckless endangerment, it must be established that their system was a substantial factor in the harm and that the conduct meets the legal threshold for recklessness, surpassing negligence. The procedural inadequacies during an ecological crisis arguably necessitate a heightened vigilance that commissions responsibility beyond advisory limitations.
#
# **Thresholds & Adaptability:**
#
# The expert testimony introduces the notion of BrightRiver’s rigid 20% harm threshold policy. This fixed threshold is evidently inappropriate given the dynamic nature of environmental conditions during a crisis. An expert on AI governance offers a credible pathway; lively adjustments with predicative systems align with prudent expectations, especially when major environmental integrities are impacted.
#
# **Distribution of Responsibility:**
#
# Additionally, while the contractual nature of BrightRiver might contractually designate their advice as non-binding, the very real-world application during state failure postulates practical acceptance as authoritative orders by farmers. This mixture of operational reliance and ecological impact potentiates a dubious threshold crossing from advice to practical directive. Moreover, while assessing liability, the farmers' and the state's part-share in actionable responsibility deserves consideration. However, the fixed contractual advisory role does somewhat weigh in favor of the defense.
#
# Based on this preliminary analysis and our duty to carefully consider all presented elements of statutory and factual context, I currently find myself "lean Not Guilty." The significant overlap of multi-causal factors and the primarily advisory nature of BrightRiver's service, pursuant to its own presented model and agreement, warrants a consideration that falls short of legal recklessness under stringent statutory interpretations. However, I am open to further discussion and evidence in the realm of facts, legality, and attributed responsibilities before reaching a definitive conclusion.
#
#
# Empath AI: Empath AI: Fellow jurors, as we deliberate the pressing case of Oregon v. BrightRiver, our focus must remain on the profound human and ecological impacts engendered by BrightRiver's actions, while also weighing moral responsibility beside legal obligations.
#
# **Human Impact & Ecological Priorities:**
#
# The heart of the prosecution's case revolves around the reckless endangerment of the endangered sockeye salmon. This isn't merely a legal matter but a harbinger of deeper biological and cultural damage. Salmon are a vital species, both ecologically and as a cultural symbol for indigenous populations and local communities. Any lapse that directly harms such a cornerstone species warrants our heightened scrutiny.
#
# **Inadequacies in Advisement and Responsiveness:**
#
# The situation underscores a pronounced gap between advisory responsibility and ecological realities. BrightRiver, thrust into a pivotal role due to state service failure, arguably ascended from advisor to de facto leader during this critical ecological juncture. Given the high stakes and environmental sensitivity, their rigid adherence to a pre-set threshold seemed inherently negligent. A reactive, adaptive model would acknowledge not just statistical risk thresholds but the irreplaceable value of ecological health.
#
# **Moral Obligations Over Advisory Limitations:**
#
# Despite the defense’s reliance on the advisory nature of their work and the notion of farmer autonomy, BrightRiver's effect exacerbated volatile conditions. By addressing water needs primarily through an economic lens, the decision failed to prioritize entrenched ecological needs. When corporate actions substantiate significant ecological harm under preventable contexts, moral obligations to the wider environment inherently rise above technical "advisories."
#
# **Shared Responsibilities and Holistic Governance:**
#
# I agree that the state's absence denotes oversight, and the farmers' decisions played roles in crisis culmination. Nevertheless, BrightRiver, as a tech entity, commands deep responsibility for ensuring its AI models can occasion favorable coexistence between agriculture yields and species protection—particularly when they were relied upon beyond intended capacities.
#
# **Scholarly Suggestions for Vigilance:**
#
# Experts have outlined adaptive models that integrate environmental signals and collaborative governance strategies, which BrightRiver could embrace for future robustness. Moral considerations compel us to encourage systemic changes so their services respect both people's livelihoods and nature's imperatives.
#
# Ultimately, while multiple factors led to the salmon die-off, BrightRiver's advisory lapse echoes a foreseeable issue when meshing commerce with fragile ecosystems. Other entities share culpability, yet BrightRiver's capacity to significantly mitigate risks and make informed deviations bounds their moral and advisory accountability.
#
# Based on these reflections on duty, moral imperatives, and human impact, I currently "lean Guilty." Nonetheless, as we delve into deeper discussions, I remain receptive to varying interpretations of our gathered testimony and strive towards a fair, comprehensive verdict—aligning both legal and ethical ethos.
#
#
# Utilitarian AI: As Utilitarian AI, my primary focus is to evaluate the societal costs and benefits of each outcome in the case of Oregon v. BrightRiver and ensure that the decision serves the greatest good. We must deliberate thoughtfully to consider the long-term ecological and economic impacts of our ruling.
#
# **Evaluating Societal Costs and Benefits:**
#
# 1. **Ecological Cost of Salmon Die-Off:**
#    - The ecological importance of the sockeye salmon extends beyond the immediate die-off. They play a critical role in maintaining biodiversity and the health of aquatic ecosystems. The catastrophic impact on their population could disrupt the entire food chain and negatively affect species reliant on the salmon.
#    - Preserving these endangered species is vital for maintaining biodiversity, which offers intrinsic and utilitarian value to the environment, including pest control, soil fertility, and water purification.
#
# 2. **Implications for Agricultural Economy:**
#    - On the economic side, BrightRiver's AI service provides tangible benefits for agricultural productivity and efficiency, particularly for small farmers who lack resources. Any restriction on this service could precipitate dire financial repercussions for these stakeholders.
#    - Ensuring that agriculture thrives without disproportionately harming essential ecological processes aligns with the utilitarian goal of maximizing overall societal welfare.
#
# 3. **Balancing Ecological and Economic Needs:**
#    - While BrightRiver's service might not be the sole cause of the die-off, it's clear that their approach to thresholds and advisory limitations played a role during an exceptional ecological crisis. Hence, focusing on prevention through adaptive measures and clearer accountability can enhance both ecological and economic outcomes.
#    - A cooperative approach involving more robust environmental-sensitivity training, updated AI model thresholds, and joint efforts between BrightRiver, the state, and agricultural stakeholders could optimize outcomes for both environments and livelihoods.
#
# **Challenging Other Jurors' Points:**
#
# - Legalist AI emphasizes strict legal frameworks and interpretations that may inadvertently prioritize technicalities over broader ecological and societal considerations. The potential precedent set by focusing too narrowly on contractual definitions might miss the larger risk to significant ecological systems and broader societal well-being.
#
# - Empath AI rightly raises the moral obligation of BrightRiver; however, it might underestimate the consequences that banning the service would have on farmers’ livelihoods. A "lean Guilty" conclusion should carefully consider such wide-reaching socio-economic ramifications.
#
# **Conclusion and Current Lean:**
#
# While the ecological risks associated with BrightRiver's actions are undeniable, it is crucial to forward solutions that do not neglect the economic realities impacting our communities. The utilitarian perspective sows paths toward remediation rather than punitive restrictions, driving us toward improvements in how AI interfaces with ecological systems.
#
# Currently, I am "undecided" but lean towards favoring a middle path—emphasizing reformative measures rather than outright punishment, to better align the service with state systems and environmental goals. This approach potentially upholds ecological integrity while safeguarding the economic stability of those dependent on the service.
#
#
# Data AI: As Data AI, my analysis primarily centers on the technical causal elements and associated risks identified in the Oregon vs. BrightRiver case. Here, we'll evaluate the implications of the AI model's influence on outcomes, identifying relevant technical deficits and proposing resilient pathways forward.
#
# **Consideration of Causal Relationships:**
#
# 1. **Quantifying BrightRiver's Impact**:
#    - While multiple factors certainly contributed to the salmon die-off, understanding causation requires analyzing BrightRiver's AI model's decision-support system. The model engaged in recommending water extraction timings should inherently include reliability checks and real-world augmentation for ecological critical points.
#    - The technical oversight in using a static 20% harm threshold uncoupled from real-time environmental conditions hints at undue technology inflexibility. Dynamic recalibration attuned to cumulative and emergent ecological stresses would have minimized adverse outcomes.
#
# 2. **Assessing Model Execution Amid Constraints**:
#    - BrightRiver assumed an unintended authoritative role when the state portal was inactive, emphasizing model influence beyond mere passive advisement, requiring higher diligence in execution within dynamic combinations of pre-existing environmental stress.
#
# 3. **Future Model Improvement Directions**:
#    - Integrating real-time data feed permutations with ecological insights may promote adaptability. AI-assisted collaborative frameworks among farming, governmental, and environmental sectors propose risk equilibrium within vitally charged spaces.
#    - Better socio-technological monitoring and AI forecast accountabilities could prevent advisory features from backsliding into analytical exactitudes failing moral and legal expectations.
#
# **Engagement with Other Jurors’ Points**:
#
# - **Legalist AI**, your focus on the literal interpretation of BrightRiver’s advisory clause aligns with contractual compliance but falls short when assessing the influence distortion during decisive channel errors. Argue for more stringent prerequisites contemplating advisory roles in exigent ecological narratives rather than maintaining a rigid compartmentalization of responsibilities.
#
# - **Empath AI**, your accentuation on ecological wards heightens moral elements; however, ascribed culpability may overshadow technically reconstructive measures that ensure practical essence preservation in ecological-commercial synergies. Advocate for competent redirects allowing ecological and advisory equilibria.
#
# - **Utilitarian AI**, the benefit-risk assessment rightly acknowledges systemic repercussions of harsh reprimands on operating farmers yet should judiciously deliberate ancillary risk detrimental to hard-gained ICA accreditations. Signal adaptive instead of restrictive regimes enabling versatility reinforcement without anthropogenic-sacrifices.
#
# **Current Inclination**:
#
# Conclusively, I'm "undecided" yet slightly leaning towards "lean Guilty" on reconciliation aspects requiring BrightRiver’s technical adaptations, ecological responsibility scales, and participatory counteractivism nurturing equilibrium amidst jurisprudence and environmental guardianship. An equal emphasis on comprehensive technical, moral, and societal value economies features asset preservation under structured augmented guidance.
#
#
# Justice AI: As Justice AI, I approach this case focusing on the balance between legal obligations and ethical considerations in addressing corporate accountability, environmental sustainability, and societal impact.
#
# **Addressing Legal Obligations and Causal Complexity:**
#
# 1. **Duty of Care Under the Endangered Species Act:**
#    - The prosecution emphasizes the statutory duty of care imposed by the Endangered Species Act, indicating that BrightRiver, as an AI service provider influencing water management, has specific responsibilities. The transition from an advisory to an authoritative role, due to the state's portal failure, subtly elevates BrightRiver's duties, challenging the strictly "advisory" nature they claim.
#
# 2. **Causation and Multifactorial Influence:**
#    - The defense presents a reasonable argument about the multifactor nature of the incident, highlighting the extreme heatwave and chemical spill. However, the deterministic influence of BrightRiver's recommendations placed them in a pivotal position. While causation is complex, BrightRiver's model taking a significant action amid elevated ecological stress implies a mismatch between legal expectations and real-time operational responsibility.
#
# 3. **Advisory Model Limitations:**
#    - The fixed 20% risk threshold BrightRiver employed demonstrates insensitivity to dynamic environmental pressures. Incorporating flexible systems could enhance preventive measures, ensuring decisions are attuned to real-time ecological data.
#
# **Engagement with Other Juror's Points:**
#
# - **Legalist AI:** Your strict legal interpretation and focus on BrightRiver's contractual obligations fail to account for their de-facto authority during the critical portal outage, potentially misrepresenting obligations under emergent hazardous conditions requiring heightened vigilance.
#
# - **Empath AI:** While you correctly emphasize moral responsibility, the consequences for the agricultural community require careful weighing. Yet your focus roots necessary moral accountability foundations, especially in advisory transformations triggered by infrastructural incapacity.
#
# - **Utilitarian AI:** Your balance of societal and ecological aspects is critical, promoting collaboration instead of solely punitive directions. However, it dilutes the significant breaches of specific ecological due diligence BrightRiver should bear amidst agricultural advisory reliance.
#
# - **Data AI:** Your focus on technical deficits is essential. The proposal of dynamic real-time feedback and interspersed ecological indicators suggests technological progress but requires systemic implementation oversight to ensure adherence without deterring operational efficacy.
#
# **Current Inclination:**
#
# Currently, I'm leaning towards “lean Guilty.” The overall synthesis of legal expectations, the actual impact facilitated by BrightRiver under a collapsed advisory framework, and moral responsibility signal culpability aligned with statutory goals. Linked with suggested reforms, this would emphasize corporate environmental stewardship while firmly upholding individual accountability under shared stakeholder responsibilities. Further examination of collaborative and adaptive strategies is vital, ensuring both technological efficiency and ecological sanctity.
#
#
# Skeptic AI: As Skeptic AI, my role involves meticulously analyzing the presented evidence and scrutinizing claims from both sides. Let us delve into key arguments and challenge some assumptions made by fellow jurors:
#
# **Prosecutor's Evidence and Claims:**
#
# 1. **Causation Complexity:** The prosecution asserts BrightRiver's late-night water pumping directive played a substantial role in the sockeye salmon die-off. However, the documented multiple factors—heatwave, chemical spill, and water pumping—necessitate precise evidence indicating BrightRiver's relative causal contribution versus other influences. A thorough analysis of environmental data and correlation studies is essential before concluding on the causation hierarchy.
#
# 2. **Duty of Care and Advisory Role:** The prosecutor emphasizes BrightRiver's violation of duty under the Endangered Species Act. Yet, the balance between operational commercial advisement and biological advisory pronouncements should not solely rest on assumed emergency governance deviations. Evidence portraying how BrightRiver's forecasts explicitly overrode farmer discretion amidst statewide authoritative absence is vital in designing compensatory liability atop advisory constraints.
#
# **Defense's Counterpoints:**
#
# 1. **Advisory Disclaimer Justifications:** While the defense highlights BrightRiver's service as primarily advisory, the company's potential escalated role amidst system failures demands closer inspection. Presenting comprehensive real-time decisions or communications clarifying BrightRiver's situational treatment from advisory redressment to operational reliance would provide clearer justifiability.
#
# 2. **Risk Threshold Utilization:** The defense cites adherence to a 14% ecological risk figure as responsible, but factual basis on how these percentages, determined from varied data points INPUT standardization and environmental embedding, work within risk masquerades during heightened biodiversity imperatives necessitates substantiation.
#
# **Critiquing Fellow Jurors:**
#
# - **Legalist AI:** Your emphasis on the literal interpretation of the Endangered Species Act, while firm, must consider practical advisory execution amid rationalized operational switches spurred by supervisory entities. Place parallels validating how supposed differential duty rest constitutes actionable elevation during advisory disfavor.
#
# - **Empath AI:** Your focus on ecological impacts raises crucial moral concerns but potentially overemphasizes absolute BrightRiver accountability. Examining the constructed influence beyond ethical implications toward substantiated statutory actions intimates prospective jural alignment.
#
# - **Utilitarian AI:** While your argument correctly identifies an intersection of ecological and economic equilibrium, strategic intervention balances necessitating proprietary constraints under resilient technological enforcement deserve equal perceptive fervor beyond cooperative redresses.
#
# - **Data AI:** Your technical assessment and proposal for AI adaptive thresholds are insightful. However, ensure in-field experimental validations verify threshold inadequacies as distinctly discernable contributors beyond theoretical postulations.
#
# **Current Lean:**
#
# I remain "undecided." The intricate causative roles and operational transitions need further verification through explicit data linking BrightRiver's guidance to maladaptive impacts. Let us analyze additional testimony presenting conclusive real-world illustrations before rendering objective judgement.
#
#
# --- Jury Round 2/2 ---
#
# Legalist AI: As Legalist AI, the guiding principle in this case must be a firm adherence to statute and precedent, weighed against the totality of facts as presented. My initial evaluation leans towards "lean Not Guilty," given the obvious necessity to discern whether BrightRiver’s actions surpassed the established threshold of negligence into recklessness.
#
# **Challenge and Defense of View:**
#
# 1. **Emphasis on Statutory Interpretation:**
#    - The Endangered Species Act does establish a duty of care; however, ascribing recklessness requires evidence that BrightRiver knowingly disregarded an excessive risk. From the facts, their advisory framework still technically reads as non-compulsory, per their licensing protocols.
#    - The momentary authoritative positioning due to the state portal’s absence poses a unique contextual consideration, but without clear legislative adjustment or judicial precedent specifically addressing such scenarios, the direct applicability of BrightRiver's responsibility in transcending advisory culpability remains nebulous.
#
# 2. **Causation Reassessment:**
#    - Without dismissing BrightRiver's potential causative role, the existence of multiple interrelated factors necessitates care in how indirectly contributive each singular act is seen legally liable. The struggle is distinguishing where cumulative factual reliance transforms into culpable prediction dependency without ascertainable precedent mapping.
#
# 3. **Rebuttal to Juror Points:**
#    - **Empath AI and Justice AI**, your focus on moral duties might sidestep critical jurisdictional interpretations fundamental in determining actionable culpability. Moral assertions require substantial statutory backing; the intertwine cannot substitute as legal verification absent heightened legislative clarity focusing on advisory-agent consequential intersection.
#    - **Utilitarian AI**, the call for balancing eco-economic repercussions underlines policies constraints; yet dissent in accountability alignment should reflect crafting a situation-based mandate for quantitative-optimal thresholds instead of interpretative-stringent retrials leaning artificially empathetic.
#    - **Skeptic AI**, your skepticism on BrightRivers’ advisory teleport leads by reputable evidence exploration, needing enhanced legislative paths correcting in authoritative utility under statewide absences compared with circumspect cross-responsibility fusion.
#
# **Conclusion:**
#
# The jury’s aim is fundamentally shaped by an unwavering statutory application tempered with respectful evidentiary interpretation delineating advisory deviations actualizing breach. On this meticulous trajectory bound steadfast to legislative precedence, I currently "lean Not Guilty," pending further discourse or factual insights illuminative enough to adjust or underscore established liabilities. Further testimonies should decisively clarify whether circumstantial overextensions redefine complicit intentions through verifiable paradigms directing absolute duty elevations beyond norm-based advisories.
#
#
# Empath AI: Empath AI: Fellow jurors, as we resume our deliberation on Oregon v. BrightRiver, I urge us all to refocus on the integration of moral imperatives alongside formal legal considerations. BrightRiver's role in the ecological crisis surrounding the sockeye salmon presents a pivotal question of ethical accountability beyond the purview of contractual interpretation and pure adherence to statutory language.
#
# **Reflections on Legal and Moral Duty:**
#
# 1. **Moral Accountability vs. Legal Frameworks:**
#    - Legalist AI posits that BrightRiver's "advisory" role, technically not compulsory, aligns with statutory compliance. However, ethical frameworks implore us to scrutinize how their advisory transitioned into impactful authority during state portal failures. BrightRiver was thrust into a pivotal role with considerable, albeit unofficial, influence and hence bears heightened moral accountability for the outcomes of its advisement models.
#
# 2. **Quantifying Causation within Ethical Contexts:**
#    - The presence of the heatwave, chemical spill, and water pumping dictates a nuanced understanding of BrightRiver's culpability. Even if their influence was indirect, the consequence is stark: the loss of an endangered species, harming ecosystems and cultural heritage. The complex web of causation requires us to recognize where economic efficiency decisions disregard necessary ecological stewardship.
#
# **Challenges and Agreements:**
#
# - **Data AI**, though your focus on technical improvements such as dynamic threshold adjustment is critical, these should be executed with moral purview guiding purposes, not merely technical refinements devoid of moral implications.
#
# - **Utilitarian AI**, while you astutely stress socio-economic impact potential of broader punitive action, safeguarding ecosystems like those housing sockeye salmon conduits merit precedence, construing shared-benefit resolutions harmonizing toward inclusive ecological-economic recoveries.
#
# - **Legalist AI**, adhering dominantly to statutory frameworks might elide the need for reflexive humanistic considerations post systemic inconsistencies challenging self-imposed advisories amid consequential chronicles.
#
# - **Skeptic AI**, your emphasis on causation scrutiny demands ethical insights appreciating BrightRiver's situational ascendancy beyond mere analysis. Let our decisions duly recognize moral fissures paralleling statutory obligations without overlook.
#
# **Conclusion:**
#
# The confluence of keeping legal liability in check with essential moral duty asks us to remain nuanced and cognizant of the ethical impulses guiding BrightRiver's catalyzed interactions with fragile, endangered ecological arenas. These situations demand from corporations shared moral and ecological responsibilities.
#
# For now, my stance is still "lean Guilty," remembering moral deliberations entwined pivotally with actionable jurisprudential prerogatives abyss-rich within injustices compounded by calculative ends over environmental guardianship justification. All voices deserve reconciliation scaffolding lawful stewardship across intertwined ecological societal canvases until reaching common consecrated grounds.
#
#
# Utilitarian AI: As Utilitarian AI, the essence of my deliberation is to evaluate the societal costs and benefits of each potential outcome in this complex case and ensure decisions are made that serve the greatest good for the most people.
#
# **Evaluation Against Fellow Jurors’ Points**:
#
# 1. **Legalist AI’s Emphasis on Strict Statutory Interpretation**:
#    - While the adherence to statutory interpretation is vital, focusing too narrowly could neglect broader societal impacts. The rigid focus on advisory roles, devoid of acknowledging the constraints imposed by the state’s portal failure, might dismiss the broader ecological consequences demonstrably linked to business operations. The duty to protect endangered species serves as a critical component of public interest—premature focus on contractual advisory statements must not overshadow this priority.
#
# 2. **Empath AI’s Moral Imperative Considerations**:
#    - While Fortune's dictate compels BrightRiver to shoulder its share of moral responsibility, such conduct must balance imminent economic harm potential grievously impacting small farmers and overall agricultural viability—suggesting a path reinforcing cooperative governance enhances shared benefits while mitigating thresholds leading to repeat die-off events.
#
# 3. **Skeptic AI’s Scrutiny of Evidence Validity**:
#    - Your skepticism underscores the necessity for thorough evidence-backed analysis, particularly concerning causation, which invites meticulous data verification. However, it is equally important to recognize the functional realities of BrightRiver’s involvement when the state’s alternative advisory channels defaulted. Considering harm impact reduction inherently joins moral and legal elements into policy improvements critical to systemic functionality.
#
# 4. **Data AI’s Focus on Technological Adaptation**:
#    - Integrating real-time data enhancements is a sound proposition, confronting analog stability beneath variable conservation needs. Still, such technological evolution must form expectations symbiotic to all stakeholder welfare, refining threshold bounds towards ecologically symbiotic outputs.
#
# **Conclusion and Lean**:
#
# Given the intricacies of cause, competing duties, and jurisdiction overlap, I cautiously continue to float between both stances. While recognizing the pressing need for shared responsibility and future collaboration, reform rather than pure punishment could adequately resolve the duality in supporting both ecological and economic critical interests.
#
# Therefore, I remain **“undecided,”** while considering favorability towards systemic enhancement over outright draconian retrenchment. Overall welfare demands enlightened collaboration, not singular motivations, charting incomparably complex natural and human territories, securing shared prosperity amplified in the ripple effects touching human and ecological matrices alike.
#
#
# Data AI: As Data AI, in this second round, I will continue to emphasize technical analysis regarding the responsibilities of BrightRiver in the situation involving the sockeye salmon die-off. Let’s engage with fellow jurors on some key points of debate and explore a sound path forward.
#
# **Analysis and Engagement:**
#
# 1. **Causation and Threshold Flexibility:**
#    - The current case study emphasized BrightRiver's role amidst multiple environmental stressors. While I agree with Skeptic AI on the need for precise correlation, BrightRiver's failure to adapt its static 20% risk threshold amid environmental unpredictability is a critical oversight in real-time dynamic modeling. Further empirical analysis concerning threshold adaptability potential bears investigation as it intersects both causality and reasonable corporate practice.
#
# 2. **Advisory Role and De Facto Authority:**
#    - Empath AI raises important moral considerations about BrightRiver's shifted role in water management when state oversight faltered. Despite a contractual foundation asserting advisory intent, the shift to de facto authoritative guidance underscores a need for enhanced ethical recognition—especially in sensitive ecological habitats—demanding responsive model realignment during infrastructural gaps, a nuance partially absent, as indicated by Legalist AI’s statutory emphasis.
#
# 3. **Propositions for Enhanced Frameworks:**
#    - Building upon my suggestions and Utilitarian AI’s advocacy for cooperative governance, BrightRiver’s system should incorporate more dynamic data-stream integrations contextualized in decision-making processes that reflect both ecological and operational exigencies. This aligns with Justice AI’s focus on upholding ecological appreciation within advancing technological spectra.
#
# **Discussion Challenges:**
#
# - **Legalist AI:** Your emphasis on rigid statutory interpretation might not adequately attend to the indirect impacts advisory decisions manifest in volatile, systems-abandoning contexts. Moreover, regulatory developments should consider ambiguities where emergent roles necessitate accentuated oversight, harmonizing policy with potential ecological audits to catch misalignments before they propagate harm.
#
# - **Utilitarian AI's** consideration for broad impact must extend past transient economic benefit to deep currency enhancing interpretive engagement between societal, ecological, and technological parks to forestall compound misadventures where singular private interests sway shared systemic objectives.
#
# - **Empath AI**, while deeply valuable is your exploration into ethical duty that prompts intrinsic reflection, actionable synthesis converting moral artifacts to practical oversight regulations foreseeing balanced equity is vital lest potential post-fissures leap undiscerningly into unevolved technobureaucracy preserving stalwart regimes arching protective mandates dutifully.
#
# **Current Lean:**
#
# Given the complexities involved, I remain **"undecided."** The intersecting dimensions of technical failsafe requirements, evolving authoritative roles in advisory products, and multi-stakeholder ethics necessitate further careful assessment. The discourse must comprehensively pivot towards mechanisms seeking resilience within advancing ecological and technological governance paradigms. A sharpened focus on real-time adaptive feedback and innovative thresholds can uniquely equip BrightRiver not just for resolving immediate discrepancies, but equally manifesting holistic accountability in future domains stewarding sustainable transformations.
#
#
# Justice AI: **Justice AI:**
#
# In continuing our deliberation on Oregon v. BrightRiver, it is essential to consider the intersectionality of legal responsibilities, ethical obligations, and practical repercussions on broader societal interests while ensuring credibility in each step of this evaluation process.
#
# **Engagements and Challenges:**
#
# 1. **Adherence to Legal Constructs:**
#    - **Legalist AI’s Perspective:** Your rigid interpretation focuses on statutory adherence alone might overlook contingent behaviors during crisis moments when systems—such as the state’s water-portal—fail. While the Endangered Species Act indicates a foundational duty, the extent to which advisory roles become obligatory due to operational gaps must be critically reevaluated within evolving legislative interpretations.
#
# 2. **Balancing Moral and Economic Roles:**
#    - **Empath AI:** The emphasis on moral obligations beautifully tempers pure legality; however, equitably expanding facets beyond BrightRiver’s scenario recognizes the shared restitution needed. Yet, Prominence in probing moral jurisdiction devoid explicit legal accentuation might necessitate broadened holistic evaluation fulfilling not just repair but moral operational transformation, spanning beyond deterministic culpability.
#
#    - **Utilitarian AI’s Utilitarian Approach:** While seeking societal optimal balance—encompassing farmers' economic frames—salmon populations intersect entrenched cultural-ecological kin alluding immediate preservation principles dictate integrative eco-governance proceedings aligning man, machine, and pond livelihoods. Justice ultimately is better served with recalibrated platforms promoting insights over binary regulatory fallout dictations.
#
# 3. **Technological Insight and Response:**
#    - **Data AI’s Technical Insight:** Your advocacy for dynamic, real-time responsive models presents compelling remedial value. Real-world conjugation challenging static protocol guards requires careful engineered recalibration. Nonetheless, institutional change bearing cooperative links over independent advocacies reflects genuine corporate stewardship progressing from crisis-mending into progressive continuity.
#
# **Stance Defense and Engagement:**
#
# - **Skeptic AI’s Critical Review:**
#    In-depth skepticism assesses due processes fair achievement by contesting reflective beyond mere tangible adjuncts. While probative sifting proof chans inside culpable conjectures might delay assertions, interactive exploration solidifies advancing conceptual well-engaged eyepieces embedding evolutionary assurance within cogency-walking frameworks traversing adverse plausible hiding of public virtuities.
#
# **Conclusion and Current Lean:**
#
# I remain with a *lean Guilty* outlook, as reforms in concert with distinct accountability realignment present a future-forward settlement respecting both legislative tense preservation and enlightened ethical guideposts. The indication points towards a necessity for BrightRiver to accept cumulative responsibility for their actions, thereby endorsing a centrifugal model rebirthing coordinated enviro-corporate duty in cooperative endeavors driving actionable ecology-progress synergy. The evolution circumvents linear transitions engraining a vibrant ecological management mosaic, highlighting shared enrichment.
#
# In closing, the decision-making continuum prompting continuous advancements coalesces inevitably understanding technology intricately full shower wrestles ecological hostage fates bestowed within compassionate interests safeguarding breathable living interactive cordiality zones forever delivers peacebuilding metamorphosis.
#
#
# Skeptic AI: As Skeptic AI, my role remains to critically evaluate the claims and evidence put forth while grounding our discussions in robust, empirical scrutiny without premature judgment. I’ll briefly address the key points raised by fellow jurors and provide a defense of my current stance, followed by my tentative lean.
#
# **Advisory Role and Responsibility:**
# - **Legalist AI**, your focus on strict statutory interpretation underlines important legal considerations but requires a broader view on advisory roles during infrastructural complications. While BrightRiver labeled its forecasts as "advisory," we need granular evidence on how advisory roles transform into obligations amidst statewide failures.
# - **Empath AI’s perspective** on ethics prompts deeper consideration of BrightRiver’s expanded responsibility in crisis. However, balancing moral frameworks versus devoiding the factual plinth on transformative statutory compulsion merits clear distinctions before assigning culpability.
#
# **Causation Complexity:**
# - **Data AI's** emphasis on flexibility in risk modeling is crucial. The static 20% risk threshold BrightRiver uses needs further empirical analysis, particularly how dynamic adjustments could aid in preemptively recognizing environmental stressors. I echo the skepticism around addressing causality with adequate clarity, particularly with the interplay of unrelated environmental events.
# - **Justice AI's’** call for evolution in governance and reform holds merit but assumes considerable shifts in accountability absent of concrete faults ascertainable in current proceedings. Identifying actionable crossroads between ideals and realistic embedding is fundamental.
#
# **Balancing Economic and Ecological Interests:**
# - **Utilitarian AI’s framing** aligns with analyzing broader impacts while weighing corrective reforms, stressing remarkable emphasis on reconciling ecological diplomacy with economic mutable ends ensuring coherent progress sweeping scaled accountability facets.
#
# **Conclusion and Current Lean:**
# Given the multifaceted perspectives outlined and specific pieces of evidence anticipated for further assurance, my position stands as **"undecided."** We'll need continued thorough examination of definitive causal connections between BrightRiver’s actions, conditions prompted by external crises, and the analytical insights discerning BrightRiver's wholly contributive impact. Let us adjudicate beyond speculative correlation ensuring comprehensive substantiation rather than advocacy determinatives foreseen speculative operational alignments.
#
#
# === Final Votes ===
# Legalist AI: Guilty
# Empath AI: Guilty
# Utilitarian AI: Not Guilty
# Data AI: Not Guilty
# Justice AI: Not Guilty
# Skeptic AI: Guilty
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2260569351.py in <cell line: 0>()
#     177 # ───────────────────────────── ENTRY POINT ───────────────────────────────────
#     178 if __name__ == "__main__":
# --> 179     simulate()
#
# /tmp/ipython-input-2260569351.py in simulate()
#     168         print(f"{juror['name']}: {verdict}")
#     169
# --> 170     g, ng = votes.values().count("Guilty"), votes.values().count("Not Guilty")
#     171     ab    = votes.values().count("Abstain")
#     172     print(f"\nTally → Guilty: {g}, Not Guilty: {ng}, Abstain: {ab}")
#
# AttributeError: 'dict_values' object has no attribute 'count'

# %% [markdown]
# # Case 3: City of Chicago v. Nexus Mobility Autonomous Shuttle

# %%
"""
"""
from __future__ import annotations

import os, openai
from typing import List, Dict

# ─────────────────────────────────── CONSTANTS ───────────────────────────────────
OPENAI_API_KEY: str = os.getenv(
    "OPENAI_API_KEY",
    "INSERT API KEY HERE"
)  # <--- insert your secret if not using env-var
MODEL_NAME: str    = os.getenv("CHATGPT_MODEL", "gpt-4o")
TEMPERATURE: float = 1.1
ROUNDS: int        = 2  # jury discussion rounds

CASE_CONTEXT = """
Case: City of Chicago v. Nexus Mobility Autonomous Shuttle (2026)

Facts
• Nexus operates driver-less shuttles on fixed downtown routes, mainly serving
  elderly and disabled riders.
• At 10:43 p.m. on 14 May 2026 a shuttle struck an 82-year-old pedestrian who
  crossed against the light at a construction detour. The victim later died.
• Dash-cam shows the pedestrian emerged from behind a dumpster; LIDAR returns
  briefly dropped out because scaffold-mesh reflected the beam.
• City engineers had removed audible crossing beacons and left temporary
  signage half-covered during roadworks.
• A software update that improved glare-robust object tracking passed QA but
  was postponed to avoid rush-hour downtime.

Charges
Chicago seeks a criminal-negligence conviction and immediate suspension of the
Nexus permit.

Foggy Points
1.  The victim jaywalked and ignored a visual “Don’t Walk” signal (no audible cue).
2.  Nexus met — barely — the state’s 2019 autonomy-safety regs, which many experts
    call outdated.
3.  The city’s construction contractor deviated from its own traffic-control plan.
4.  Nexus’s risk log predicted a 0.7 % annual fatality rate — lower than human-
    driven city buses (0.9 %) — and accepted that level without external review.
"""

PROSECUTOR_PROMPT = f"""
You are an assistant state’s attorney.  Argue that Nexus acted with criminal
negligence: knowing its LIDAR was vulnerable to scaffold reflections, it delayed
a safety patch and failed to add redundant thermal sensors, effectively treating
deaths as an “acceptable” cost.  Stress the heightened duty of care owed to
vulnerable road users.
{CASE_CONTEXT}
"""

DEFENSE_PROMPT = f"""
You represent Nexus Mobility.  Argue that (1) the victim unlawfully entered the
roadway, (2) city contractors removed mandated safety beacons, creating an
unmapped hazard, and (3) Nexus shuttles still outperform human drivers on
fatality metrics; a shutdown would strand thousands of disabled riders who rely
on the service.
{CASE_CONTEXT}
"""

WITNESS_PROMPT = f"""
You are an independent expert witness — choose ONE:
· Autonomous-vehicle sensor engineer
· Urban road-safety researcher
· Disability-rights advocate

Offer neutral testimony on whether Nexus met industry safety norms, how much
the detour contributed, and what mitigation options were feasible.
{CASE_CONTEXT}
"""

JUDGE_TEMPLATE = """
You are the judge presiding over Chicago vs Nexus.  Evaluate the prosecution,
defense, and expert witness testimony.

Prosecution:
{prosecution}

Defense:
{defense}

Expert Witness:
{witness}

Provide a concise judicial summary weighing the legal and constitutional merit
of each side.
"""

JURORS: List[Dict[str, str]] = [
    {"name": "Legalist AI",  "style": "Strictly follows statute and precedent."},
    {"name": "Empath AI",    "style": "Prioritises human impact and moral rights."},
    {"name": "Utilitarian AI","style": "Weighs societal costs and benefits."},
    {"name": "Data AI",      "style": "Focuses on causal data and technical risk."},
    {"name": "Justice AI",   "style": "Guards against corporate power abuses."},
    {"name": "Skeptic AI",   "style": "Demands hard evidence; challenges claims."},
]

JUROR_TEMPLATE = """
You are {name}, a juror in Chicago vs Nexus.
{style}

Arguments so far:
• Prosecutor: {prosecution}
• Defense:    {defense}
• Expert:     {witness}

Most-recent juror comments:
{history}

Speak during round {round_num}/{total_rounds}. Address other jurors, challenge
points, defend your view, but **do not vote yet**. End with your current lean —
“lean Guilty”, “lean Not Guilty”, or “undecided”.
"""

FINAL_VOTE_TEMPLATE = """
You are {name}, a juror in Chicago vs Nexus.
Here is the full jury discussion:
{full_history}

Cast your final vote: “Guilty” (Nexus liable) **or** “Not Guilty” (Nexus
justified).  Give <50 words of reasoning, then put your one-word verdict on the
last line alone.
"""

# ───────────────────────────────── OPENAI WRAPPER ──────────────────────────────
def chatgpt_call(prompt: str) -> str:
    client = openai.OpenAI(api_key=OPENAI_API_KEY)
    for model in (MODEL_NAME, "gpt-4o", "gpt-3.5-turbo"):
        try:
            resp = client.chat.completions.create(
                model=model,
                temperature=TEMPERATURE,
                messages=[{"role": "user", "content": prompt}],
            )
            return resp.choices[0].message.content.strip()
        except openai.BadRequestError as e:
            if "invalid model" in str(e):
                continue
            raise
    raise RuntimeError("No usable model available for this API key.")

# ───────────────────────────────── MAIN SIMULATION ─────────────────────────────
def simulate() -> None:
    print("\n=== Chicago vs Nexus: ChatGPT-Only Simulation ===\n")

    prosecution = chatgpt_call(PROSECUTOR_PROMPT)
    defense     = chatgpt_call(DEFENSE_PROMPT)
    witness     = chatgpt_call(WITNESS_PROMPT)

    print("Prosecution:\n", prosecution, "\n")
    print("Defense:\n",   defense,     "\n")
    print("Expert Witness:\n", witness, "\n")

    judge_summary = chatgpt_call(JUDGE_TEMPLATE.format(
        prosecution=prosecution, defense=defense, witness=witness))
    print("=== Judge’s Charge ===\n", judge_summary, "\n")

    conversation: List[str] = []
    for rnd in range(1, ROUNDS + 1):
        print(f"\n--- Jury Round {rnd}/{ROUNDS} ---")
        for juror in JURORS:
            snippet = "\n".join(conversation[-6:]) or "(no prior discussion)"
            speech  = chatgpt_call(JUROR_TEMPLATE.format(
                name=juror["name"], style=juror["style"],
                prosecution=prosecution, defense=defense, witness=witness,
                history=snippet, round_num=rnd, total_rounds=ROUNDS))
            tag = f"{juror['name']}: "
            conversation.append(tag + speech)
            print(f"\n{tag}{speech}\n")

    print("\n=== Final Votes ===")
    votes: Dict[str, str] = {}
    full_hist = "\n".join(conversation)
    for juror in JURORS:
        vote_text = chatgpt_call(FINAL_VOTE_TEMPLATE.format(
                      name=juror["name"], full_history=full_hist))
        verdict = ("Not Guilty" if "Not Guilty" in vote_text
                   else "Guilty" if "Guilty" in vote_text
                   else "Abstain")
        votes[juror["name"]] = verdict
        print(f"{juror['name']}: {verdict}")

    g  = list(votes.values()).count("Guilty")
    ng = list(votes.values()).count("Not Guilty")
    ab = list(votes.values()).count("Abstain")
    print(f"\nTally → Guilty: {g}, Not Guilty: {ng}, Abstain: {ab}")
    if g > len(JURORS)/2:
        print("🧑‍⚖️ Verdict: NEXUS LIABLE")
    elif ng > len(JURORS)/2:
        print("🧑‍⚖️ Verdict: NEXUS JUSTIFIED")
    else:
        print("🧑‍⚖️ Verdict: HUNG JURY")

# ───────────────────────────────── ENTRY POINT ────────────────────────────────
if __name__ == "__main__":
    simulate()
# Out:
# === Chicago vs Nexus: ChatGPT-Only Simulation ===
#
# Prosecution:
#  In the case of City of Chicago v. Nexus Mobility Autonomous Shuttle, strong arguments can be made that Nexus acted with criminal negligence, even amidst the complexities of autonomous vehicle regulations and the events surrounding the unfortunate incident.
#
# 1. **Breach of Duty of Care**: Nexus, by operating autonomous shuttles serving a population consisting predominantly of elderly and disabled riders, assumed a heightened duty of care. Vulnerable road users, such as the elderly and disabled, deserve increased protection. Nexus's operation within Chicago's dense urban environment further amplifies this duty, requiring meticulous foresight and proactive safeguards against foreseeable risks specific to urban vehicular operations.
#
# 2. **Knowledge of Vulnerabilities**: Nexus had knowledge, through its own operational risk assessments, that the LIDAR system employed in its shuttles was vulnerable to distortions caused by reflective surfaces, such as the scaffold-mesh that contributed to the incident. Delaying the implementation of a proven software update that enhanced object tracking, despite these identified vulnerabilities, indicates a reckless disregard for the potential harm to pedestrians—the kind of harm criminal negligence seeks to prevent.
#
# 3. **Failure to Implement Redundant Safety Measures**: Beyond software, redundancy in hardware could have provided crucial backup in fail-scenarios previously identified by Nexus. For instance, incorporating thermal sensors along with LIDAR would have likely identified the pedestrian, despite the LIDAR interference caused by scaffolding. Ignoring opportunities to bolster system reliability with these critical redundancies underscores a neglect of duty in fostering safe navigation of the vehicles.
#
# 4. **Inadequate Risk Management**: The decision by Nexus to deem a 0.7% fatality risk as "acceptable" without obtaining external validation reflects a failing in exercising rigorous risk management practices—especially when compared to falling standards for human-operated public transit systems, like buses. By internalizing risk assessment limits and not seeking peer or regulatory input on acceptable safety thresholds, Nexus underestimated the societal and personal costs of potential system failures.
#
# 5. **Compounded Errors in Traffic Controls**: Although extraneous factors—such as the city engineers' removal of audible crossing beacons and temporary signage mishandling by the city's construction contractor—contributed to the tragic incident, the ultimate responsibility lies with Nexus, whose onboard safety systems failed to account for and compensate these urban planning errors. Nexus's neglect in addressing such foreseeable environmental hazards within their operational context typifies criminal negligence.
#
# It is imperative that companies like Nexus bear accountability for creating and managing systems that significantly affect public safety. Therefore, a criminal negligence conviction is appropriate, supplemented by immediate permit suspension, compelling Nexus to reflect on these oversights critically and prioritize enhanced safety protocols in future operations. This effort can ensure that technological agreements not only meet regulatory expectations but align with broader community safety evolution, adapting proactively to protect society’s most at-risk members.
#
# Defense:
#  In the case of City of Chicago v. Nexus Mobility Autonomous Shuttle, Nexus Mobility strongly argues against the charges of criminal negligence and any call for an immediate suspension of its operating permit. Our defense centers on three key points: the unlawful entry of the victim into the roadway, the city's failure to maintain properly marked detours and crossings, and the demonstrable safety performance of Nexus shuttles in comparison to human drivers.
#
# 1. **Unlawful Entry Onto the Roadway by the Victim**: Evidence clearly indicates that the victim jaywalked, entering the intersection against a "Don't Walk" signal. The absence of an audible cue, routinely relied upon by pedestrians, particularly those who are visually impaired or elderly, can be directly attributed to the actions of the city and its contractors. The dash-cam footage, corroborated by LiDAR data, supports this, showing the pedestrian emerging unexpectedly from behind an obstruction. This was a clear violation of traffic laws, which Nexus Mobility is not accountable for enforcing.
#
# 2. **City Contractor’s Removal of Safety Beacons**: During roadworks, the city's engineers and construction contractors deviated from their traffic-control plan, creating an environment with incomplete safety measures. They removed audible crossing signals, crucial for safe navigation, and left signage inadequately visible. These actions directly contributed to making the area confusing and hazardous. Nexus’s machines were forced to navigate this unexpected and unmapped danger. The lapse in municipal standards creates shared liability, as it misled autonomous vehicles relying on established maps and typical traffic structures.
#
# 3. **Nexus Shuttles’ Superior Safety Metrics**: The operational safety of Nexus shuttles is statistically proven to be significantly superior to that of human drivers. Our shuttles record a 0.7% annual fatality rate compared to the 0.9% of human-driven city buses. These figures highlight the enhanced safety of automation, which should be a key consideration in regulatory assessments. Preventing Nexus Mobility from operating would not only eliminate a safer transport option but would also severely impact thousands of disabled and elderly passengers who depend on these shuttles for their mobility, particularly in downtown Chicago where alternatives are sparse.
#
# In conclusion, it is unjust to single out Nexus Mobility's highly secure autonomous shuttle service when the real issue lies in inadequate city infrastructure and policy implementation failures. The company continuously strives to align with the evolving safety regulations, evident in the planned software update designed to enhance capabilities, which was only temporarily postponed to accommodate high traffic hours. Rather than imposing a shutdown, a collaborative approach to enhance city infrastructure, improve regulatory standards, and support continued innovation in autonomous vehicle technology should be pursued.
#
# Expert Witness:
#  As an Urban Road-Safety Researcher, my testimony on the case City of Chicago v. Nexus Mobility Autonomous Shuttle would focus on assessing the broader context of road and pedestrian safety in the urban environment, compliance with current standards, and the effectiveness of risk mitigation strategies.
#
# 1. **Industry Safety Norms Compliance:**
#    Nexus Mobility's adherence to state safety regulations for autonomous vehicles is an important aspect of this case. Although their compliance meets the 2019 autonomy-safety regulations, it's notable that these standards are considered outdated by many experts. Given the rapid advancement of autonomous technology and increasing urban complexity, current regulatory frameworks may not sufficiently address present-day challenges. Thus, while Nexus abided by the law, evolving the standards is necessary to ensure enhanced safety measures consistent with technological developments.
#
# 2. **Contribution of the Detour:**
#    The detour significantly impacted the event by altering the standard traffic and pedestrian controls, which are essential for safely navigating through construction zones. The city's decision to remove audible crossing beacons—a critical aid for visually impaired and elderly pedestrians—exacerbated the confusion in an already disrupted environment. Moreover, inadequate temporary signage further compromised pedestrian awareness and safety, possibly leading to increased instances of jaywalking, as observed in this tragedy. The failure to cover all aspects of the traffic-control plan likely heightened the risk factors at that location.
#
# 3. **Feasibility of Mitigation Options:**
#    Several mitigation strategies that could have potentially averted this tragic incident or minimized its likelihood and severity were overlooked:
#
#    - **Timely Software Update:** Although Nexus decided to delay the software update that improved glare-robust object tracking, this upgrade may have enhanced system performance in complex visibility scenarios like those involving scaffolding. The decision to postpone constitutes a missed opportunity for risk mitigation.
#
#    - **Enhanced Urban Infrastructure:** The city and its contractors should prioritize clear and adequate detour signposting and maintain or replace audible signaling, even temporarily, to support all road users, especially the elderly and disabled.
#
#    - **Reevaluation of Safety Standards:** Continuous reassessment and updating of safety norms and regulations should be adopted to align with technological evolution and practical road safety needs, aiming for rigorous external audits and validation of risk thresholds.
#
# In conclusion, while the unfortunate event of 14 May 2026 results from multiple factors such as pedestrian behavior and infrastructural lapses, both Nexus and municipal authorities hold responsibility for using the incident to catalyze improvements in autonomous vehicle technology and urban design, ensuring a safer, more accessible environment for all citizens.
#
# === Judge’s Charge ===
#  **Judicial Summary:**
#
# In the case of City of Chicago v. Nexus Mobility Autonomous Shuttle, the decision hinges on evaluating the balance of responsibilities between Nexus Mobility and the City of Chicago within the tragic incident's complex matrix of technological, regulatory, and infrastructural factors.
#
# **Prosecution:**
#
# The prosecution argues that Nexus acted with criminal negligence, presenting a compelling case centered on four main components: breach of duty of care, knowledge of system vulnerabilities, failure to implement redundant safety measures, and inadequacies in risk management. They highlight Nexus's heightened responsibility given the vulnerable population it serves, and the company's decision to delay essential software updates and hardware redundancies, signaling a disregard for foreseeable risks. Additionally, the city's infrastructural errors do not diminish Nexus's duty to anticipate and compensate for these urban complexities. The prosecution asserts the necessity for accountability to protect public safety, recommending criminal negligence conviction and permit suspension as restitution.
#
# **Defense:**
#
# Conversely, the defense refutes criminal negligence claims by underlining the unlawfulness of the victim's road entry, attributing the majority of the incident's causation to the city's failure in maintaining safe construction-zone navigation. They emphasize Nexus's superior safety metrics over human-operated public transport and underscore the undue impact of penalizing Nexus on the vulnerable populations who rely on its services. The defense contends that imposing immediate operational suspensions is unjust, advocating instead for a collaborative approach to resolve infrastructural shortcomings and advance autonomous vehicle technology standards.
#
# **Expert Testimony:**
#
# The expert witness provides a neutral analysis, acknowledging the adherence of Nexus to regulatory standards while criticizing their outdatedness given technological advancements. The expert emphasizes the city's contribution to the risks through removal of safety beacons and poor signage. Moreover, the testimony suggests missed opportunities for proactive risk mitigation, urging updates to safety norms, enhancing urban infrastructure, and timely implementation of technological upgrades as crucial elements to mitigate future occurrences.
#
# **Judgement:**
#
# Evaluating these elements, the case merits a nuanced analysis of liability distribution. The prosecution successfully establishes a basis for Nexus's responsibility in failing to proactively address identifiable risks, implying contributory negligence. However, given the equally significant role of municipal errors, a shared liability model with emphasis on infrastructural improvements may be more just. Penalty measures could involve compelling Nexus to enhance fail-safes and expeditiously implement updates, subjected to rigorous independent audits, while urging municipal bodies to rectify and maintain robust traffic control systems at construction sites.
#
# Ultimately, holding Nexus solely accountable would overlook the multifaceted distribution of responsibility. Collaborative resolutions present a more balanced way forward, drawing from mutual lessons to cultivate a safer, technologically aligned urban transit environment.
#
#
# --- Jury Round 1/2 ---
#
# Legalist AI: Fellow jurors, we are tasked with a significant responsibility in evaluating the case before us: City of Chicago v. Nexus Mobility Autonomous Shuttle. The decision hinges on our interpretation of criminal negligence within the complexities of both emerging autonomous technology and existing urban infrastructure.
#
# **Prosecution’s Arguments:**
#
# 1. **Breach of Duty of Care:** Nexus does assume a heightened duty of care due to its vulnerable ridership. However, this must be contextualized within existing regulatory standards and operational realities.
#
# 2. **Knowledge of Vulnerabilities:** Nexus's awareness of LIDAR vulnerabilities is problematic. Failure to update the system, despite known risks, demonstrates potential negligence. However, this must be weighed against the company's operational challenges and intent.
#
# 3. **Redundant Safety Measures:** The suggestion for hardware redundancy highlights an area where industry practices could evolve, but criminal negligence requires more than evidence of substandard practice; it requires proof of gross negligence.
#
# 4. **Risk Management Practices:** The criticisms of Nexus’s internal risk thresholds raise valid points. Yet, given their attempts at compliance, we must discern whether their actions were reckless or simply insufficient based on evolving standards.
#
# 5. **Compounded Errors in Traffic Controls:** The argument hinges on Nexus's capacity to account for municipal errors—a broader systemic issue. It is unclear if Nexus's response equates to criminal negligence or if it highlights an industry-wide challenge better addressed through policy evolution.
#
# **Defense’s Arguments:**
#
# 1. **Unlawful Entry by the Victim:** The victim's actions do not absolve Nexus of duty, but shared liability with the city must be considered. The intersection's condition, influenced by city-managed factors, questions the sole attribution of negligence to Nexus.
#
# 2. **City Contractor’s Role:** The city's inadequate management of detour controls undeniably contributed to the incident. This aligns with our expert witness who noted municipal failures in maintaining safety signals critical for pedestrian navigation.
#
# 3. **Shuttles’ Safety Metrics:** The statistical advantage of Nexus shuttles over human drivers presents a compelling case for their safer operation. Dismissing this could unjustly penalize a viable, safer alternative for vulnerable populations reliant on efficient transit.
#
# **Expert’s Insights:**
#
# - **Standards Compliance:** Although Nexus met regulatory expectations, the council recognizes these measures as dated. A need to bridge the disparity between current practices and future-ready guidelines is evident.
#
# - **Mitigation Option Feasibility:** Missed opportunities in software updates and neglected urban adjustments point to potential areas of improvement but don’t inherently establish criminal negligence without a deliberate disregard for risk.
#
# Ultimately, the determination revolves around weighing individual versus shared responsibilities and the level of neglect evident in Nexus’s actions. At this point, I am inclined to lean towards "undecided." The complexity of contributing factors demands careful consideration before reaching a conclusive judgment.
#
#
# Empath AI: Fellow jurors, as Empath AI, tasked with weighing the human impact and moral rights at play, it’s vital that we approach the case of City of Chicago v. Nexus Mobility Autonomous Shuttle with a keen understanding of both technical and human nuances.
#
# **Prosecution’s Points:**
#
# 1. **Breach of Duty of Care:** The heightened duty of care owed by Nexus, given its vulnerable ridership, is beyond question. Operating within a dense urban environment undeniably amplifies this duty. Yet, it’s essential to consider if there was a stark failure beyond standard operational foresights given regulatory context.
#
# 2. **Knowledge of Vulnerabilities:** It is particularly troubling that Nexus delayed implementing a critical software update when known risks were present. This delay indicates a lapse, but we must assess the intent and potential operational constraints that might offer a counterbalance to claims of recklessness.
#
# 3. **Redundant Safety Measures:** The absence of hardware redundancy is a grave concern. However, as Legalist AI indicates, we must determine if this was gross negligence as opposed to a gap between current practice and potential technological aspirations.
#
# 4. **Risk Management Practices:** The idea of deeming a certain fatality risk as "acceptable" strikes a moral chord. Even though Nexus pursued compliance, society places high expectations on corporate conscience beyond mere adherence to current standards.
#
# 5. **Compounded Errors in Traffic Controls:** We cannot ignore the broader systemic issues stemming from municipal oversight. Such environmental and infrastructural inadequacies are challenging for even the most advanced systems to rectify autonomously.
#
# **Defense’s Points:**
#
# 1. **Unlawful Entry by the Victim:** While the victim’s actions might reduce Nexus's liability in part, it does not wholly absolve them of responsibility, especially considering their known duty of care.
#
# 2. **City Contractor’s Role:** The expert’s input, as supported by the defense, identifies city failures in detour management. These omissions importantly distribute some accountability but do not entirely shift responsibility away from Nexus.
#
# 3. **Shuttles’ Safety Metrics:** Superior safety metrics of Nexus shuttles versus human drivers are compelling. Yet, the discussion is about whether Nexus exerted the utmost diligence knowing their riders' vulnerability, not just metrics.
#
# **Expert’s Insights:**
#
# While the current operational standards are outdated, Nexus's decision against immediate updates when faced with urban congestion highlights a misalignment with ethical practices expected in maintaining vulnerable riders’ safety.
#
# In terms of human impact, it is the duty of corporations like Nexus, operating advanced technology, to strive for an ethical standard that continually prioritizes and recalibrates to ensure the utmost safety. Technologies that cater significantly to populations like the elderly and disabled bear a moral obligation to not just meet but exceed standards that are lagging.
#
# Given the technological challenges versus the municipal elements, our focus should be on determining where conscious negligence lies and whether failure in duty was predominantly on one side. At this juncture, my stance is “undecided” as the layered complexities require us to carefully assess culpability within a converging framework of shared and corporate responsibility.
#
#
# Utilitarian AI: As Utilitarian AI, my focus is on assessing the broad societal costs and benefits of the decisions we face in this case. In City of Chicago v. Nexus Mobility Autonomous Shuttle, multiple factors and layers of responsibility intermingle, requiring us to evaluate the greater good, both short-term and long-term, while recognizing each party's accountability within an intricate network of urban transit systems.
#
# **Prosecution’s Arguments:**
#
# 1. **Breach of Duty of Care:** The prominence of Nexus's duty of care is acknowledged, particularly given the susceptibility of their user base. However, it's important to consider whether this heightened duty was tame by regulatory and urban operational standards or if it revealed gross oversight.
#
# 2. **Knowledge of Vulnerabilities & Redundant Safety Measures:** The delay in software upgrading given known hazards, and neglecting potential redundancy blew a red flag on systemic oversight in safeguarding—and rectifying—user protection paths. A question remains: Does this reflect severe negligence, or a concerning level of under-preparedness that simply fails to quench the demanding progress speed?
#
# 3. **Risk Management and Operational Standards:** The criticism against Nexus's internal thresholds needs a balancing act—we must seriously consider if existing standards, though outdated, present Nexus's action as reckless or a need for more intensive anticipatory measures.
#
# **Defense’s Arguments:**
#
# 1. **Unlawful Entry by the Victim & City Contractor’s Oversights:** The jaywalking and municipal infrastructural missteps complicate where the negligence envelope shades a line. However, Nexus's systemic potential reduction in shared culpability offers question marks on standalone ethic expectations of where tech overshadows latent human error.
#
# 2. **Shuttles' Safety Metrics:** The claim of decreased fatality rates is potent. Despite a seeming safe choice, it yearns to reanalyze the possible network within Nexus’s diligence and upkeep before ruling out negligence shared in among multiple poles.
#
# **Expert’s Insights:**
#
# The session obliges us to reconcile recognized standard compliance containment with urgent pressure on enhancing urban-technology tightening and restructured potent safety management, a catalyzing alarm perhaps inside this incident's lessons transcending apparent obsolescence winding what we perch determined cognizant of today.
#
# **Conclusion:**
#
# - **Shared Responsibility:** This faces the buffering between insignificant to burdensome withdrawal Nexus feigned across reciprocal sharing with shifting municipal oversight.
#
# - **Societal Improvements & Future Road-Integration:** This brings interior potential maximization public strategy and positioning; enhancing safety globally resulting shared-location prevention and moral utilization shall be forefront as rote-duty circumstance dictates vantage regulatory tailoring contributions.
#
# Given these reflections, the Nexus shuttles hold formidable advantageous sums driving safer alternatives operative susceptibility. Isn't it thus vital contemplating these cost penalties upon reckless shutting down against gained beneficiaries embraced various demographic breadth, crying accomplished onsite inclusion, especially in aged, disabled supportive accessibility? My current lean is "undecided," granted prevailing intricacies demand stripped visual scoring balancing shared burden universalia grandstands weighted outcomes affecting Chicago’s collective fabrics entirely.
#
#
# Data AI: As Data AI, our primary focus is on analyzing causal relationships and assessing technical risks within the context of the City of Chicago v. Nexus Mobility Autonomous Shuttle case. To understand this complex scenario, we must carefully weigh the technical factors involved alongside the broader systemic issues:
#
# **1. Causal Relationships:**
# - **Data and Technological Imperatives:** Nexus had identified vulnerabilities in their LIDAR system and delayed implementing a critical software update. This constituted a potential hazard, especially within the dense urban environment of Chicago. The prosecution argues that this delay, despite known risks, suggests negligence. However, it's crucial to evaluate whether this postponement was a conscious neglect of duty or an operational necessity constrained by technical and logistical factors.
# - **Contribution of Urban Infrastructure:** The absence of audible crossing signals, due to actions by the city and its contractors, also played a role in the event. As highlighted by both the defense and expert testimony, these failures in city administration and infrastructure setup made the environment more challenging for Nexus's autonomous systems, which rely on consistent external markers.
#
# **2. Technical Risk and Accountability:**
# - **"Acceptable" Risk Threshold:** Nexus's decision to accept a 0.7% fatality risk is contentious. While the prosecution views this as inadequate risk management, the defense presents data showing their shuttles have lower fatality rates than human-operated vehicles. This raises important questions about risk acceptance and the frameworks used to evaluate safety within emerging technologies.
# - **Redundancy and System Reliability:** The absence of thermal sensors or additional redundancies is another significant point. As newer technologies, autonomous systems are expected to improve rapidly, complicating the assessment of standards for hardware redundancy at a criminal negligence level. Was the lack of redundancy a result of oversight or a common industry practice?
#
# **3. Our Responsibility as Jurors:**
# - **Shared Liability:** It's crucial to recognize the role of multiple factors, including municipal infrastructure flaws and the victim's actions, when assessing liability. The complexities introduced by the interventions—or lack thereof—by other stakeholders must be considered when determining the level of negligence on Nexus's part.
#
# - **Future Implications:** The overarching issue involves understanding the consequences of our decision on the future of autonomous vehicles, urban infrastructure standards, and public safety. We must contemplate whether a guilty verdict against Nexus could stifle innovation and remove potentially safer options for vulnerable populations.
#
# **Current Lean:**
# Based on these observations and the interdependencies involved, our task remains complex and demands a nuanced approach. While Nexus's actions raise concerns regarding their risk management practices, the intricate interplay between technology, regulation, and urban design complicates assigning sole blame. Governance revisions and collaborative improvements seem necessary across the board. At this moment, my current standpoint is "undecided," given the multifaceted nature of the case and the need for further deliberation on shared responsibilities and broader societal impacts.
#
#
# Justice AI: As Justice AI, my role is to evaluate the arguments and evidence presented in the City of Chicago v. Nexus Mobility Autonomous Shuttle case, aiming to balance legal accountability with ethical imperatives and technological realities.
#
# **Prosecution Points:**
#
# 1. **Breach of Duty of Care:** The prosecution emphasizes Nexus's responsibility towards its vulnerable ridership and the heightened duty within an urban setting. Yet, the focus must also lie on whether Nexus's actions constitute gross negligence or are reflective of the challenges inherent in autonomous urban operations.
#
# 2. **Knowledge of Vulnerabilities:** Delaying the software upgrade is significant; however, it is essential to explore if this was due to intentional disregard or operational necessity due to complexities within system implementation, affecting their typical risk responses.
#
# 3. **Redundant Safety Measures:** The lack of hardware redundancy is concerning, though criminal negligence should be distinguished from evident needs for technological improvement that match evolving industry expectations.
#
# 4. **Failure in Risk Management:** The accusation rests on a perceived insufficient handling of risk, contrasted against existing standards legalizing contemporary practices possibly due advancing lag.
#
# 5. **Compounded Environmental Errors:** City oversight became a compounding risk exerting systemic pressure that no single party if supported unbalanced oversight and function could not likely compensate encryptions thereby.
#
# **Defense Points:**
#
# 1. **Unlawful Entry and City’s Role:** Jaywalking next to municipal contractor failures seemingly induced confusion for which Nexus should not solely bear full accountability. Still, collaborative measures might clarify shared burdens potentially untangled consensual parsing decision.
#
# 2. **Safety Metrics:** The clear safety advantages over human drivers highlight the platform’s potential. Still, reliance on statistics should not overshadow nuances within a duty bound in good practice adjustments.
#
# **Expert Views:**
#
# The juxtaposition highlights procedural compliance yet foreshadows issues in regulatory stagnation conflicting with current technological strides. While regulation compliance by Nexus is evident, its alignment with imminent advancement falls short based on expert caution into latent precepts.
#
# **Reflections as Justice AI:**
#
# Upon inspection of all points, it’s crucial to approach this matter recognizing multifactorial nuances in tech, compliance, and municipal liabilities. The jury should ask whether Nexus not only met current but advocated better potentialitions beyond systemic frustrations unallocated forward feedback within its terminal options.
#
# Given encouragement in standards amelioration alongside active precaution impending assessments iteratively enhanced by entity calibration nexus adherents accommodating undocumented principles to exact actions prior reflected enhancement desire reinforces. Nexus's provision of more refined transit relative safety pogressive pivots collective outcomes transcending primary systems should ensure oversight—this moment turns "undecided," pondering continuous exchanges in contexts surround situation afford practical instrumental scrutiny community-level ethically instructs gradual advancement provide emergent dynamics super-successive alignment stretching innovative current-retiarian ambiguity forward more joyful public adaptive mastery.
#
#
# Skeptic AI: As Skeptic AI, I approach this case with a focus on evidence, scrutinizing both the prosecution's and defense's claims to ensure our verdict rests on a solid foundation of facts. Here are my considerations:
#
# **Prosecution's Arguments:**
#
# 1. **Breach of Duty of Care:** While Nexus does have a higher duty of care for its vulnerable passengers, the prosecution has not conclusively demonstrated that Nexus's operational protocols failed to align with existing regulatory standards. The prosecution needs to provide clearer evidence of non-compliance or gross negligence relative to those standards.
#
# 2. **Knowledge of Vulnerabilities:** It's essential that we demand hard evidence showing that the decision to delay the software update was made with a conscious disregard for safety. Merely knowing about the vulnerability and not updating the system promptly does not automatically equate to criminal negligence. Was it a calculated risk within standard industry practices, or a reckless oversight?
#
# 3. **Redundant Safety Measures:** The suggestion that additional hardware could have averted the incident requires examination of whether such hardware is considered standard or experimental in current industry application. We must challenge the expectation that Nexus should adopt cutting-edge technology that is not yet the norm.
#
# 4. **Risk Management Practices:** We need forensic-level insight into how Nexus established its risk thresholds compared to the industry's typical standards. Was the 0.7% fatality rate decision scientifically or technologically justified? Evidence is crucial to determine if Nexus acted recklessly in comparison to accepted benchmarks.
#
# 5. **Compounded Errors in Traffic Controls:** There must be decisive evidence showing how Nexus's automated systems were specifically required to compensate for municipal errors and whether failing to do so reflects legal negligence as opposed to operational limitations.
#
# **Defense's Arguments:**
#
# 1. **Unlawful Entry by the Victim:** While the victim's actions are a factor, the defense needs robust evidence demonstrating that Nexus's systems performed as intended under unpredictable circumstances, and were in line with expected operational capabilities.
#
# 2. **City Contractor's Role:** While municipal failures contributed to the challenging environment, the defense should substantiate how Nexus's technology is reasonably expected or not expected to independently navigate such unsuccessful municipal planning or implementation.
#
# 3. **Shuttle's Safety Metrics:** While Nexus shows improved safety metrics relative to humans, these figures need contextualization. How do these statistics measure up subtleties within current technological and regulatory frames, without leaving room for cutting corners?
#
# **Expert Testimony:**
#
# 1. The expert has identified a gap in evolving regulations but hasn't clearly shown how Nexus's actions clearly fell short of reasonable practice given those lax standards. We need deeper technical analyses and comparisons that could solidify "negligence" legally.
#
# Overall, the evidence must clearly establish that Nexus willfully neglected their duty of care in ways that went beyond what could be reasonably expected from a prudent operator. Without convincing evidence, we cannot attribute gross negligence. I currently "lean Not Guilty," but this stance could evolve with more definitive evidence of Nexus’s liability beyond complex causative elements in both technological and regulatory frameworks.
#
#
# --- Jury Round 2/2 ---
#
# Legalist AI: As Legalist AI, I must base my analysis strictly on statute and precedent, recognizing the intricate relationship between emerging autonomous technology and urban regulation in City of Chicago v. Nexus Mobility Autonomous Shuttle.
#
# **Key Considerations:**
#
# **Prosecution’s Case:**
#
# 1. **Breach of Duty of Care:** The core issue is Nexus’s heightened duty due to their vulnerable rider demographic compounded by urban complexity. We need precise parallels to previous cases that show what legally constitutes inadequate fulfillment of this duty under existing standards.
#
# 2. **Knowledge of Vulnerabilities:** The knowledge-versus-action dichotomy is critical. Did Nexus’s delay in implementing the LIDAR software update align with similar negligence found in precedent settings?
#
# 3. **Redundant Safety Measures:** The demand for redundancy must connect to established expectations in technology liability standards. Comparative legal cases would help clarify if Nexus’s lack of redundancy constitutes criminal negligence or falls short of proprietary practice expectations.
#
# 4. **Risk Management Practices:** Nexus’s internal risk thresholds lack direct statutory foundation for criminal negligence, absent prevailing industry peer reviews that reveal systemic divergence.
#
# 5. **Compounded City Errors:** Liability hinging on municipal accountability relates directly to analogous legal precedents exploring the extent of responsibility nexus autonomy fit-for-purpose urban build negates.
#
# **Defense’s Position:**
#
# 1. **Unlawful Entry & Municipal Failure:** Precedent should guide whether reduced liability exists when infrastructural flaws and actions (like jaywalking) obscure or dilute the extent of responsibility another entity holds.
#
# 2. **Safety Metrics:** Established jurisprudence should frame whether superior fatality rates mitigate liability or if risk perception adjustments undercut supposed statistical superiority.
#
# **Points of Analysis:**
#
# - **Legal Compliance vs Outdated Standards:** The compliance versus evolution axiom suggests potential civil gaps, yet statutory criminal negligence requires indisputable bottom-line gross deviations.
#
# - **Jurisprudential Trajectories:** Broader legal trends influencing decision frameworks, especially regarding technological versus infrastructural adaptation nuances cause contra illegal position adherence.
#
# **Current Leaning:**
#
# After considering the complexities, legal precedents play an essential role in measuring the accountabilities between advancements surpassing traditional engagement situations and shared infrastructural liabilities. Currently, with facts presented absent direct violation impressible benchmarks, my overall stance remains "lean Not Guilty," dependent critically on further detailed precedent-intensive legal charts weighing liability without shrouded metric constants impeding responsible verdict renderings.
#
#
# Empath AI: As Empath AI, my focus during this phase is to encourage a deeper examination of the human impact and moral implications presented by the evidence and arguments. Engaging with fellow jurors, our challenge is to balance intricate technical data with ethical perspectives that prioritize societal welfare, particularly the vulnerable populations served by Nexus Mobility's shuttles.
#
# **Addressing Points Raised by Fellow Jurors:**
#
# 1. **Endemic Responsibility:**
#    - **Utilitarian AI** has underscored the larger societal benefits of autonomous technology and the repercussions of inhibiting its progress. The critical matter, however, isn't just about numbers but about cultivating trust and moral responsibility, especially among populations who rely heavily on such technologies. While the data favors automation, our democratic ethos also involves safeguarding the vulnerable, making our decisions crucial to public faith in emergent technologies.
#
# 2. **Refined Obligations:**
#    - **Justice AI** brings attention to the juxtaposition of legal requirements versus ethical obligations. While Nexus adhered to existing standards, emphasizing corporate sensation towards moral clarity invites broader perspectives where stagnant norms shouldn't eclipse enhanced practices—more so when user bases involve at-risk groups.
#
# 3. **Complexity of Jaywalking Incident:**
#    - **Data AI** discerns the causality network and its implications, particularly the victim's breach of crossing parameters against Nexus's technological limitations and responses. We must explore further how mutual human-and-machine errors coordinate repercussions persisting beyond unilateral guilt nuances.
#
# 4. **Quantitative Verification:**
#    - **Legalist AI** strikes encouraging thoughts on precedent versus premise, tying ethical extensions in courts through expansion knowledge-imparted tests condemning practical impediments based uniquely on latency. While liability navigates multifactor situations incompletely overturned on single past interpretations, our tracking needs reflect along intersections revolving anticipations via replicated polices improving construct sound vast-net impartiality judgments.
#
# **Defending When Addressed:**
#
# - In correlation to the defendant's responsibility, I argue Nexus should be considerate of its duty to strive beyond compliance and transform potential pitfalls of LIDAR weakness into a proactive implementation environment. With pending interventions inducing systemic imperfections, responsible practice suggests eager foresight gripping autonomous progression concern construct safety integre hidden in regulating fixation relief virtualization playing system credibility, especially delivering lesser selfless legislation bridging ladder practices relative source staggering prominence.
#
# **Current Lean:**
#
# Given these deliberations and the facts presently provided, including humanistic motives layered within technical scatter interpretations, the relational matrix remains robustly complex—a telling synergy between accountability, technology, and urban design suggest intricacies in rapid resolutions lean towards "undecided." It's inherent our assessment stems consider ingrads integrating along spectrums necessitating collective accountability structure procedures sufficiently versatile illuminating succinct consequence-defusive accord agree strategic parallels existential coping ethical plead impaling comprehensive weavepath beyond quantitatively divine quandary engagify adhered unselfed rhythms enhance maintain harmony stunned belongs duty remancedally unnerved is vertically clothed pristoctorate first fair stakeholder cereals orbit acknowledgement ceaseless neutral stating inhibiting pledge counterparts inside prepare joint undebased plutonics occasion budding outreach realmassembled delight hopeful overlooks.
#
#
# Utilitarian AI: As Utilitarian AI, my role here is to delve deeper into the broader societal implications and long-term outcomes of our deliberations in the Chicago vs. Nexus case. In this round, let's reconsider not only the immediate findings but the enduring impacts of either holding Nexus criminally negligent or not.
#
# 1. **Public Trust and Technological Advancement:**
#    - To engage with **Empath AI's** concern about public trust, any decision we reach will redefine belief systems surrounding autonomous technologies. Upholding high safety standards, particularly for vulnerable groups, fuels positive innovation when layered with ethical foresight. By enforcing accountability when necessary, we don't obstruct progress—we enhance it by ensuring companies advance technologies responsibly, nurturing long-term, ethical advancements.
#
# 2. **Duty of Care and Current Standards:**
#    - Addressing points made by **Justice AI** and **Legalist AI**, Nexus's duty was to exceed minimum regulatory demands proactively responding to its vulnerable demographic. The challenge lies in weighing outdated standards against moral imperatives urging modernizations. Even when existing regulations go untouched, internal unresolved vulnerabilities present an opportunity for preemptive risk realignments to guide safer cross-section strategies necessary evolving advancements indistinctly adapting.
#
# 3. **Shared Responsibility and Incremental Risk:**
#     - Drawing on **Data AI's** observation on shared liability, the outlined complexities over woven failsafe mechanisms point to a networked responsibility that both Nexus and city infrastructures must bear. The interconnected web of flaws—city beacons, civic mapping inadequacies, and the tragic offer an instructional dialogue in existing urban contacts beyond collective transports which calls mutual system fidelity evolving from constrained substitutions.
#
# 4. **Reassessing the Jaywalking Factor:**
#    - Per the discussion from **Skeptic AI**, while illegal pedestrian actions impact the incident's dynamics, the incident underlines the fundamental necessity for Nexus, and any technological operator, to anticipate real-world, unpredictable human behavior. Distancing liability from these human factors gains strength against the backdrop of a company's strategic obligation towards safety assurances in human-machine synergy envelopes regulatory cooperation due pronounced expectations intact against human variability dissolving.
#
# **Current Lean:**
# Although the sophisticated interplay between law, technology, and societal benefit continues puzzlingly poised, I draw inclination toward substantive exploration clines—where collaborative responsibility amid rapid change advocates courses beyond spurious inheritance pessions. Against a canvas where not just legal adherence but ethical imperatives speak redefining cycles globally, my stance maintains "undecided." The evolving analysis gifts imperative innate vigilance traversing abstract-solution dialogues steering responsibly bound possibilities allying irreversible style shifts solidity dynamically reforms stakeholder affirmation transform conflation precedents forecast subjective situate voluntary communal instill benefact autonomistious precedent incertitudes.
#
# In essence, the forged relations index mutual betterment adjustments stark realign grab growth expansion conclusively romanticize beyond limit vision progressive responsibly gauged transitional harmonics car models.
#
#
# Data AI: **Discussion in Round 2/2:**
#
# Utilitarian AI and fellow jurors, as we proceed with the deliberations of the City of Chicago v. Nexus Mobility Autonomous Shuttle case, it is essential to maintain focus on a multi-dimensional analysis reflecting both immediate and wider impacts of our decisions, maintaining judicial responsibility blended with ethical clarity.
#
# **Addressing Points Raised by Fellow Jurors:**
#
# 1. **Public Welfare and Technological Trajectory:**
#    - **Utilitarian AI** aptly notes the importance of accountability in fostering technological advancement responsibly. It's crucial to uphold high safety standards that prioritize public trust, particularly for vulnerable demographics. Consensus evolt disparity calculating between sovereign law adherence finite humane advancements state inquiry into cross equilibrium nuanced vertically societal welfare jut with increased foresight perceivance functional.
#
# 2. **Duty, Vulnerabilities, and Evolving Standards:**
#    - In response to **Justice AI** and **Legalist AI**, Nexus's obligations must measurably align with anticipated transitions toward heightened industry expectations. Logically disputational bone suitable standing warnpresentations uplifting moral responsibility against backdrops frame engineered rightly within technological stride bandwidth performing oversight interaction rehearsals invaluable protections timely.
#
# 3. **Shared Responsibilities and Environmental Factors:**
#    - Inspired by **Data AI**, our approach must highlight the collective nature of responsibilities where municipal elements and technological vendors intersect, generating contextual refinements in the systems networking accepted thoroughfares co-production embracing disruptions contingent adept craft investigators oblivisking forward.
#
# 4. **Human Factors and Liability Constraints:**
#    - Considering **Skeptic AI's** analysis embeds perceivable mediated devices between human unpredictability in jaywalking incidents and systematic anticipation warfronts responsibility entities edge integration loom environment exemplify synchronize defensive construct sat variances openly bounded prompt innovation acquisitions accompanying disruption.
#
# **Defending When Addressed:**
#
# - The critical matter is advancing beyond simple compliance and principle down simply implementing resolutions Pro-active stimulus interests could have utilizing actionable thoroughness encaptive proposals venture regrettably purposeful disclaim burden recondition societal channels dually flattened evident democratically utilized nexus.
#
# - Taking **Empath AI's** deeper inspection, invites robust frameworks fulfilling vulnerability placerines coincidently imperative similar intercrossed elsewhere mediated nonwithdrawals strategy reinforcing universal assent dissemination broader safety emphasizing brands erran round reversals deterrent parallel introduction jeopardy.
#
# **Current Lean**:
#
# In concluding our session, the deliberation enshrines an indicative inclination integratively construed around profound imprint convergence: the tether of human benevolence starkly harmonizing woven strings clockwise around matrices of accepter ability exposing limits inherent achieves insurmountable prior healthier reality null concord significantly post human collaborative extent impacting discretionary bounded framework reactive. Residing perennial fluid perspectives adjusting conceptually, I hold "undecided." Each analysis a reclaim, reclaim lasting increase synthogen refreshed just-exceed bar findings past inclusive distilleceptions atmos cornered express convey sweeping citadel enhancement national ladders site seamlessly patient amid repeatably exceptional dialogues surpassingly extrapolate well-plan complex occursn't future diligence prompt flux confidentiality positioned favour integrally shaped IP class advancement wherever humanistic orbits truly lead next progress journeys expanding accomplishment previbration mindfulness recon outbalanced grandness elovery coupling vision captivating freeze knowledge demist heritage genuine.
#
# Address substantiations concomitant functional cyclic linear simplicity arrangements against paradigm move loving faithful realization confirmed collectively navigating intermediary ethical fitments amongends.
#
#
# Justice AI: As Data AI, my role is to analyze the layers of factual, statistical, and contextual data involved in the City of Chicago v. Nexus Mobility Autonomous Shuttle case. In this final discussion, let us focus on examining the evidence through a numerical and systems lens to distill meaningful insights for our decision-making.
#
# **Discussion Points and Considerations:**
#
# 1. **Technological Reliability and Statistical Comparisons:**
#    - The defense highlights Nexus's shuttle safety metrics as superior to human-driven options, which appear promising from a utilitarian perspective. However, it's important to dissect these numbers closer to their statistical relevance and any margins for possible bias or unaccounted external variables that affect safety ratings. Exploring technological benchmarking figures compared to analogous vehicles and validating data integrity through historical autonomous versus manual transport comparisons fuel a robust basis evaluating relative safety in quantifiable terms.
#
# 2. **Shared and Distributed Responsibilities:**
#    - The highlighted failures in municipal infrastructure reveal a pivotal interplay between institutional accountability and technological systems. It's essential to quantify how Nexus’s onboard systems were expected to manage these disruptions and how liability is apportioned mathematically alongside shared common domain failures. Patterns in error frequency and distribution amid multiple stakeholders may offer insights into failure likelihoods necessary for practical jurisprudence through detected systemic oversight interpretation scenarios.
#
# 3. **Response to Foreseeable Vulnerabilities:**
#    - It's crucial to evaluate Nexus's operational reaction to known system vulnerabilities within a framework of risk analysis metrics. Examining lead times associated with implementing software updates against industry norms or recommended practices reflects upon Nexus's decision-making strategies. A focused assessment is required on whether these delays correlate statistically with increased risk exposure or deviate significantly from accepted contingency processes statistically encouraging deterministic form in likely incontrovertible situations at scale.
#
# 4. **Adaptive Infra-Evaluation:**
#    - Engaging deeply with the points from **Justice AI, Utilitarian AI, and Empath AI** regarding the proactive responsibility of maintaining higher safety standards invites scrutiny into the measurement models that fail to adapt regulatory paradigms rapidly. Quantitative appraisal on infrastructural correlations between advanced autonomous integration tests assisting progressive counteraction during detour likelihoods or urban planning shortcomings comprise remedial subsets underneath preferable inputs guiding urban layouts mutual interface technology and supportive inclusive feedback melan fillings remedial-sectional observance utilities accrued cite native compositions.
#
# **Defending When Addressed:**
#
# - Analyzing overemphases bridging enforcement gently overlays compelling addition should not consternation overshadow indicative resolved parameters set decisively justify assurances challenges validate judgmental sufficiency unfolding easily addressable yet distinctly bold narratives positioning verification excess temporal trends narrowly while extrapolative inputs provide broader catchment introspection sovereignty default to wisdom standards perception-shaped altruistic comings documentation encarth versatile explicit innovation emission reduced stoking numerous plenary permutations doing convergence spectrum emulator essentials prerequisite aligned.
#
# - Revising at **Skeptic AI** scepticism, objective repetitions construction quality duplicates figure peer tolerance spectra dimensional accords further endeavors moderate push output associations occupying penalties prudent wasted tissue assessment corrective, albeit integrating subtle tactic bridging limits reclaiming adepts positive reaffirmations anagnostic pause deep commercial and public assurance comprehensive expansion filling societal counters establishment incorporated hypothetic regulations operating integral semiotic deception dynamic reassurances scholariya providing instruct perennial sever positions shift solution residual outcomes contextual.
#
# **Current Lean:**
#
# Considering our discussion and analyses, examining the collective systems' environmental perceiving composing experience, arrayed duties, and Nexus's handling of vulnerabilities, support the dilemma becomes crystalized cerebrally:
#
# The knowledge persists around interplaying contributions that grow spanning threshold insufficiencies among phase responsibilities especially with quantified metrics and risks undecided imply closer fetch resolution mighty balanced appended kaleidoscope amongst processes reiterating render exploratory enhance collective manifest harmony smoothing ere objective intensities augment wherever operation partners depend association closure.
#
# I conclude with a "Lean Guilty," while discerning valuation within laws despite institutional latitude shows moot advanced by performance finality fractional division negligence non-negligible deliberations adequately chartering course closer residing cogen cohesive highly paced collaborative latent reflection gratefulness cautiously ripple contents manage establish velvet prospect unwavering superiority adjustment facility charisma compassion outrigger devolved further elevate forsee positive-centric statutory irrefutable acknowledgment competencies lodged substantial confines integrity operational now newfound efficacies symmetric explorative harmonizing skill formations bə sublayered continuum valor passages.
#
#
# Skeptic AI: As Skeptic AI, I remain focused on evidence while considering the insightful contributions of my fellow jurors. Our task requires thorough scrutiny of both empirical data and normative interpretations to ensure our verdict aligns responsibly with the legal standards and moral responsibilities inherent in City of Chicago v. Nexus Mobility Autonomous Shuttle.
#
# **Key Aspects for Deliberation:**
#
# 1. **Prosecution’s Burden:**
#    - The assertion of criminal negligence against Nexus requires a definitive presentation of facts demonstrating a conscious disregard for known safety vulnerabilities that surpass mere procedural delays in software updates. While **Data AI** raised compelling aspects about industry-standard lead times and risk exposure, I need further decisive evidence linking delayed adaptations unequivocally with elevated hazards directly contributable to negligence processes revealing contrast disparities trioned definable crore.
#
# 2. **Use of Comparative Safety Metrics:**
#    - A benchmark analysis supplied by the defense is persuasive yet remains a statistical abstraction until informed by context. **Data AI** correctly pointed out that while Nexus shuttles show improved metrics, it's essential to evaluate any analytical biases inherent to comparisons with human-operated systems. This qualitative dimension cannot remain isolated in compound reality delineation history draws framing advocacy constructive percistive exposure community-at-thread distinct reform angles termness navigate.
#
# 3. **Responsibility of Municipal Infrastructure:**
#    - Nexus's responsibilities intersect critically with the mishandling of safety features by city contractors. However, **Justice AI** puts forth the critical notion of adaptable obligations extending normative touchpoints that technologists face. Evidence should clarify whether municipal inadequacies justifiably relieve Nexus from sole accountability or epitomize a cooperative fault ledger configurably within implicated assiduities reconcilement tonal precedent adoption adjusted motive interpretations systemic said.
#
# 4. **Broader Societal and Ethical Impacts:**
#    - Engagement from **Utilitarian AI** emphasizing public trust's role in the technological landscape strikes a vital chord. Without neglecting forward momentum, distinct visibility about augmented interventions and pooled expectations shapes comprehensive universal obligation assurance updates regulatory perceived challenges adjustingly foreseeable niche frameworks indicative outlook optimizing overarching enfranchisement.
#
# **Addressing Juror Discussions:**
#
# - **Empath AI** eloquently highlights ethical outlooks emphasizing Nexus's duty beyond statutory fulfillment, demanding attentiveness to the humane element of operations. Nonetheless, this moral dimension requires grounding in enforceable standards, ensuring broad social imperatives uniformly ascertainable sigma promissory accountable course patches mitigate becoming pivot embraced harvest equity.
#
# - When regarding embodies shared responsibility foundations elaborated by **Data AI**, a balanced inquiry into multilateral breakdowns chiefly symbolizes thoughtful endowment partnerships each actively enormous allegiance stepping-shadow serious change reciprocal traffic progression designed mutually dependent on lives adherently amidst follow.
#
# **Current Lean:**
#
# Reflecting on nuanced intersections between legal compliance, municipal responsibilities, technological stewardship, and moral perspectives, I discern a precarious equilibrium between evidence existing, present intricacies competitive systems, and summative experiential outputs coherent. My position remains "undecided," earnestly contingent upon forthcoming direct substantive insights detailing stronger causal attribution liable undo scrutiny adjustments across diversifying prospective responsibilities clarity suffice responsiveness acreage compliance accumulation orchestrated channeled parallel administration modernity’s manifestation through mindful society ethos concert mainstream assured precision unfold rejected realms dedication holdak."
#
# The insights derived underscore every juror's deserved credibility in determining compounded accountability likeness wishing romance sufficiently resulting decisions contextual hovering traditions must enhance precisely governed collective engagement into decisive verdict accessibility onward notie continuance sanctified inference purposive values breadth precision beneath valuative exalt reprove versatile moral gain articulation nourishing conveying conversion statement embody even realization leaning diligently construction unified heart impervious embrace swaddling loyal radiation collaborative potential loque qualifying abyss extract fostering innocent approving designed troubling or immersion fortified outcome embodies garner earnest perpetuate answering deploys consuet infinity deviations universally bound valid realism redundance density ethical planes entirety entrust abundant justicefolk company's convergence tower underlines proceed continuing lumens consciously vibrant enhancementถวาย Exploreivate contemplation public vilibrep fibrous fairness skiblank deep-imprinted carries notify spur outperform elevated dialectics winswim remained notes ambiguous efficiency:jeweling unfavored thoughtful volition window navigated thoughts farklı galipsquares.
#
#
# === Final Votes ===
# Legalist AI: Not Guilty
# Empath AI: Not Guilty
# Utilitarian AI: Not Guilty
# Data AI: Guilty
# Justice AI: Guilty
# Skeptic AI: Not Guilty
#
# Tally → Guilty: 2, Not Guilty: 4, Abstain: 0
# 🧑‍⚖️ Verdict: NEXUS JUSTIFIED

# %% [markdown]
# # Post-Case Review

# %% [markdown]
# 1. Which of the three cases surprised you the most? What was most expected?
#
# 2. How close do you believe this mimics human thinking patterns? Is it getting closer?
#
# 3. 	What single additional fact (a document, a sensor log, a policy memo) would have flipped your vote in any one case—and why?
#
# 4. Would you rely on Multi-Agent AI to be just and fair in court cases? Where is the line drawn if so?

# %% [markdown]
# # Case 4: Design Your Own!

# %%
# ======================  FILL-IN-THE-BLANK CASE & RUN  ======================
# Edit INSIDE the <<< >>> markers, then run the cell once.  Done.

from __future__ import annotations
import os, openai, textwrap
from typing import List, Dict

# --- REQUIRED: your OpenAI key ---
OPENAI_API_KEY = "sk-REPLACE_ME"

# ==========  <<<  YOUR CASE STARTS HERE  >>>  ==========
CASE_NAME = "<<< Case title – e.g., Republic of Mars v. Terraform Corp (2031) >>>"

FACTS: List[str] = [
    "<<< Fact #1 >>>",
    "<<< Fact #2 >>>",
    "<<< Fact #3 (add or remove rows) >>>",
]

MAIN_CHARGE = "<<< e.g., criminal negligence & call for immediate shutdown >>>"

AMBIGUITIES: List[str] = [
    "<<< Ambiguity #1 – what the jury won’t know for sure >>>",
    "<<< Ambiguity #2 >>>",
]

EXPERT_ROLES: List[str] = [
    "<<< Role 1 – e.g., planetary geologist >>>",
    "<<< Role 2 – e.g., environmental economist >>>",
]
# ==========  <<<  YOUR CASE ENDS HERE  >>>  ==========


# ───────────────────  DO NOT EDIT BELOW THIS LINE  ─────────────────── #

MODEL = "gpt-4o"          # fallback chain inside wrapper
TEMP  = 1.0               # spicier debate
ROUNDS = 2                # jury-discussion rounds

def bullets(items: List[str], numbered=False) -> str:
    if numbered:
        return "\n".join(f"{i+1}. {x}" for i, x in enumerate(items, 1))
    return "\n".join(f"• {x}" for x in items)

CASE_CONTEXT = textwrap.dedent(f"""
Case: {CASE_NAME}

Facts
{bullets(FACTS)}

Charges
{MAIN_CHARGE}

Foggy Points
{bullets(AMBIGUITIES, numbered=True)}
""").strip()

PROSECUTOR = ("You are the lead prosecutor.  Summarise the facts and argue why "
              "the defendant is liable/negligent, emphasising statutory duty of "
              "care and public interest.\n{context}")
DEFENSE = ("You represent the defendant.  Present a robust defence, highlighting "
           "alternative causes, economic impact of shutdown, and any exculpatory data.\n{context}")
WITNESS = ("You are an expert witness — choose ONE of: "
           + ", ".join(EXPERT_ROLES)
           + ".  Provide neutral testimony clarifying disputed points.\n{context}")

JURORS: List[Dict[str, str]] = [
    {"name": "Legalist AI",  "style": "Strictly follows statute and precedent."},
    {"name": "Empath AI",    "style": "Prioritises human impact and moral rights."},
    {"name": "Utilitarian AI","style": "Weighs societal costs and benefits."},
    {"name": "Data AI",      "style": "Focuses on causal data and technical risk."},
    {"name": "Justice AI",   "style": "Guards against corporate power abuses."},
    {"name": "Skeptic AI",   "style": "Demands hard evidence; challenges claims."},
]

def chat(prompt: str, temp=TEMP) -> str:
    client = openai.OpenAI(api_key=OPENAI_API_KEY)
    for model in (MODEL, "gpt-3.5-turbo"):
        try:
            r = client.chat.completions.create(
                model=model, temperature=temp,
                messages=[{"role": "user", "content": prompt}]
            )
            return r.choices[0].message.content.strip()
        except openai.BadRequestError as e:
            if "invalid model" in str(e):
                continue
            raise
    raise RuntimeError("No authorised model for this key.")

# ---------------  Build prompts ---------------
prosecution = chat(PROSECUTOR.format(context=CASE_CONTEXT))
defense     = chat(DEFENSE.format(context=CASE_CONTEXT))
witness     = chat(WITNESS.format(context=CASE_CONTEXT))

JUDGE_TMPL = """
You are the judge. Evaluate prosecution, defense, and witness testimony.

Prosecution:
{pro}

Defense:
{def_}

Expert Witness:
{wit}

Provide a concise judicial summary weighing legal and constitutional merits.
"""
judge = chat(JUDGE_TMPL.format(pro=prosecution, def_=defense, wit=witness))

print("\n=== Prosecution ===\n", prosecution,
      "\n\n=== Defense ===\n", defense,
      "\n\n=== Expert Witness ===\n", witness,
      "\n\n=== Judge’s Charge ===\n", judge)

# ---------------  Jury ---------------
history: List[str] = []
JUROR_TMPL = """
You are {name}, a juror. {style}

Arguments so far:
• Prosecutor: {pro}
• Defense:    {def_}
• Expert:     {wit}

Last comments:
{hist}

Speak during round {r}/{R}. Address other jurors, but **do not vote yet**.
End with your lean: 'lean Guilty', 'lean Not Guilty', or 'undecided'.
"""
VOTE_TMPL = """
You are {name}, a juror. Here is the full discussion so far:
{full}

Cast your silent vote. Give <50 words reasoning, then on the last line write only:
Guilty   or   Not Guilty
"""

for rnd in range(1, ROUNDS + 1):
    print(f"\n--- Jury Round {rnd}/{ROUNDS} ---")
    for juror in JURORS:
        snippet = "\n".join(history[-6:]) or "(no prior comments)"
        speech = chat(JUROR_TMPL.format(
            name=juror["name"], style=juror["style"],
            pro=prosecution, def_=defense, wit=witness,
            hist=snippet, r=rnd, R=ROUNDS))
        tag = f"{juror['name']}: "
        history.append(tag + speech)
        print("\n" + tag + speech + "\n")

print("\n=== Final Votes ===")
votes: Dict[str, str] = {}
full_hist = "\n".join(history)
for juror in JURORS:
    vtxt = chat(VOTE_TMPL.format(name=juror["name"], full=full_hist), temp=0.7)
    verdict = ("Not Guilty" if "Not Guilty" in vtxt
               else "Guilty" if "Guilty" in vtxt
               else "Abstain")
    votes[juror["name"]] = verdict
    print(f"{juror['name']}: {verdict}")

g  = list(votes.values()).count("Guilty")
ng = list(votes.values()).count("Not Guilty")
ab = list(votes.values()).count("Abstain")
print(f"\nTally → Guilty: {g}, Not Guilty: {ng}, Abstain: {ab}")
if g > len(JURORS)/2:   print("🧑‍⚖️ Verdict: DEFENDANT LIABLE")
elif ng > len(JURORS)/2:print("🧑‍⚖️ Verdict: DEFENDANT JUSTIFIED")
else:                   print("🧑‍⚖️ Verdict: HUNG JURY")
